# %%
from pyspark.sql import SparkSession
from pyspark.sql import Row
from delta import *
from os import PathLike
from hdfs import InsecureClient
from pyspark.sql.types import LongType, StringType, BooleanType, StructField, StructType, ArrayType, IntegerType, FloatType, DoubleType
from pyspark.sql.functions import when, col, concat, lit

# warehouse_location points to the default location for managed databases and tables
warehouse_location = 'hdfs://hdfs-nn:9000/AreasVerdes/warehouse'

builder = SparkSession \
    .builder \
    .master("local[2]") \
    .appName("Python Spark DataFrames and SQL") \
    .config("spark.sql.warehouse.dir", warehouse_location) \
    .config("hive.metastore.uris", "thrift://hive-metastore:9083") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .config("spark.jars.packages", "io.delta:delta-core_2.12:1.0.0") \
    .enableHiveSupport() \

spark = configure_spark_with_delta_pip(builder).getOrCreate()

# %%
hdfs_path = "hdfs://hdfs-nn:9000/AreasVerdes/bronze/InfQuintais_csv/InfQuintais.csv"

# %%
# Carrega o dataset da informação do quintal
customSchema = StructType([
    StructField("ParksID", StringType(), True),        
    StructField("InspectionID", IntegerType(), True),
    StructField("NextToAnotherGarden", BooleanType(), True),
    StructField("TotalFenceLength", FloatType(), True),
    StructField("TotalSidewalkArea", FloatType(), True),
    StructField("TotalSidewalkLength", FloatType(), True),
    StructField("OnSiteService", BooleanType(), True),
    StructField("HydrantW_in15ft", BooleanType(), True),
    StructField("HydrantOnGardenSide", BooleanType(), True),
    StructField("RainHarvesting", BooleanType(), True),
    StructField("RainGallons", FloatType(), True),
    StructField("SolarPanels", BooleanType(), True),
    StructField("CompostSystem",  BooleanType(), True),
    StructField("ComposTumblers", BooleanType(), True),
    StructField("NonFoodPlants", BooleanType(), True),
    StructField("Food", BooleanType(), True),
    StructField("OpenLawnOrCommunalArea", BooleanType(), True),
    StructField("PavedArea", BooleanType(), True),
    StructField("TreesInGarden", BooleanType(), True),
    StructField("FruitTrees", BooleanType(), True),
    StructField("StreetTrees", BooleanType(), True),
    StructField("EmptyTreePits", BooleanType(), True),
    StructField("Murals", BooleanType(), True),
    StructField("BlankShed", BooleanType(), True),
    StructField("ParksSign", BooleanType(), True),
    StructField("Chickens", BooleanType(), True),
    StructField("Pond", BooleanType(), True),
    StructField("FishInPond", BooleanType(), True),
    StructField("Turtles", BooleanType(), True),
    StructField("Aquaponics", BooleanType(), True),
    StructField("FarmersMarket", BooleanType(), True),
    StructField("CSApickup", BooleanType(), True),
    StructField("Composting", BooleanType(), True),
    StructField("GreenHouse", BooleanType(), True),
    StructField("StructureForSeasonExtension", BooleanType(), True)
])

episodes = spark \
            .read\
            .option("delimiter",",")\
            .option("header","true")\
            .schema(customSchema) \
            .csv(hdfs_path)

# %%
# mostra a schema e a tabela
episodes.printSchema()
episodes.show()
#episodes.toPandas()
# Out:
# root
#  |-- ParksID: string (nullable = true)
#  |-- InspectionID: integer (nullable = true)
#  |-- NextToAnotherGarden: boolean (nullable = true)
#  |-- TotalFenceLength: float (nullable = true)
#  |-- TotalSidewalkArea: float (nullable = true)
#  |-- TotalSidewalkLength: float (nullable = true)
#  |-- OnSiteService: boolean (nullable = true)
#  |-- HydrantW_in15ft: boolean (nullable = true)
#  |-- HydrantOnGardenSide: boolean (nullable = true)
#  |-- RainHarvesting: boolean (nullable = true)
#  |-- RainGallons: float (nullable = true)
#  |-- SolarPanels: boolean (nullable = true)
#  |-- CompostSystem: boolean (nullable = true)
#  |-- ComposTumblers: boolean (nullable = true)
#  |-- NonFoodPlants: boolean (nullable = true)
#  |-- Food: boolean (nullable = true)
#  |-- OpenLawnOrCommunalArea: boolean (nullable = true)
#  |-- PavedArea: boolean (nullable = true)
#  |-- TreesInGarden: boolean (nullable = true)
#  |-- FruitTrees: boolean (nullable = true)
#  |-- StreetTrees: boolean (nullable = true)
#  |-- EmptyTreePits: boolean (nullable = true)
#  |-- Murals: boolean (nullable = true)
#  |-- BlankShed: boolean (nullable = true)
#  |-- ParksSign: boolean (nullable = true)
#  |-- Chickens: boolean (nullable = true)
#  |-- Pond: boolean (nullable = true)
#  |-- FishInPond: boolean (nullable = true)
#  |-- Turtles: boolean (nullable = true)
#  |-- Aquaponics: boolean (nullable = true)
#  |-- FarmersMarket: boolean (nullable = true)
#  |-- CSApickup: boolean (nullable = true)
#  |-- Composting: boolean (nullable = true)
#  |-- GreenHouse: boolean (nullable = true)
#  |-- StructureForSeasonExtension: boolean (nullable = true)
#
# +-----------+------------+-------------------+----------------+-----------------+-------------------+-------------+---------------+-------------------+--------------+-----------+-----------+-------------+--------------+-------------+-----+----------------------+---------+-------------+----------+-----------+-------------+------+---------+---------+--------+-----+----------+-------+----------+-------------+---------+----------+----------+---------------------------+
# |    ParksID|InspectionID|NextToAnotherGarden|TotalFenceLength|TotalSidewalkArea|TotalSidewalkLength|OnSiteService|HydrantW_in15ft|HydrantOnGardenSide|RainHarvesting|RainGallons|SolarPanels|CompostSystem|ComposTumblers|NonFoodPlants| Food|OpenLawnOrCommunalArea|PavedArea|TreesInGarden|FruitTrees|StreetTrees|EmptyTreePits|Murals|BlankShed|ParksSign|Chickens| Pond|FishInPond|Turtles|Aquaponics|FarmersMarket|CSApickup|Composting|GreenHouse|StructureForSeasonExtension|
# +-----------+------------+-------------------+----------------+-----------------+-------------------+-------------+---------------+-------------------+--------------+-----------+-----------+-------------+--------------+-------------+-----+----------------------+---------+-------------+----------+-----------+-------------+------+---------+---------+--------+-----+----------+-------+----------+-------------+---------+----------+----------+---------------------------+
# | B544-GT001|           1|              false|          213.25|            276.0|               23.0|        false|          false|               true|          true|      500.0|      false|         true|         false|         true| true|                  true|     true|         true|     false|      false|        false| false|     true|    false|    true|false|      null|  false|     false|        false|    false|      true|      true|                      false|
# | M397-GT001|           3|              false|             0.0|            300.0|               25.0|        false|           true|              false|          true|      200.0|      false|        false|         false|         true|false|                 false|    false|         true|     false|      false|        false| false|    false|     true|   false|false|      null|  false|     false|        false|    false|     false|     false|                      false|
# | M331-GT002|           5|               true|            15.5|            160.0|               10.0|        false|          false|              false|          true|       60.0|      false|        false|         false|         true|false|                  true|    false|         true|     false|      false|         true| false|    false|     true|   false|false|      null|  false|     false|        false|    false|     false|     false|                      false|
# |M297A-GT001|           8|              false|           204.0|            910.0|               70.0|        false|          false|               true|         false|       null|      false|        false|          true|         true| true|                  true|    false|         true|      true|       true|        false| false|    false|     true|   false|false|      null|  false|     false|        false|    false|      true|     false|                      false|
# | X277-GT001|           9|               true|           265.0|           3750.0|              150.0|        false|          false|               true|         false|       null|      false|        false|          true|         true| true|                  true|    false|         true|      true|       true|         true|  true|     true|     true|   false|false|      null|  false|     false|        false|    false|      true|      true|                      false|
# | B535-GT001|          15|              false|           180.0|           1700.0|              200.0|        false|           true|               true|          true|      300.0|       true|         true|         false|         true| true|                  true|    false|         true|      true|       true|        false| false|     true|     true|   false|false|      null|  false|     false|        false|    false|      true|     false|                      false|
# | B575-GT001|          16|              false|           251.0|            742.5|               49.5|        false|          false|              false|          true|     1200.0|       true|         true|          true|         true| true|                  true|     true|         true|      true|       true|         true| false|     true|     true|   false|false|      null|  false|     false|         true|     true|      true|     false|                      false|
# | B553-GT001|          20|              false|            null|            364.0|               26.0|        false|          false|              false|          true|     1000.0|       true|         true|         false|         true| true|                  true|    false|        false|     false|       true|        false| false|    false|     true|   false|false|      null|  false|     false|        false|    false|      true|     false|                      false|
# | M313-GT001|          22|               true|             0.0|            608.0|               76.0|        false|           true|              false|         false|       null|       true|         true|         false|         true|false|                 false|     true|         true|      true|       true|        false| false|    false|     true|   false| true|      true|   true|     false|        false|    false|      true|     false|                      false|
# | M293-GT001|          23|              false|             0.0|           3240.0|              270.0|         true|           true|               true|          true|      500.0|      false|         true|         false|         true| true|                 false|    false|         true|      true|      false|        false|  true|    false|     true|   false| true|      true|   true|     false|        false|    false|      true|     false|                      false|
# | B438-GT001|          24|              false|           125.0|           2280.0|              152.0|        false|           true|               true|         false|       null|      false|        false|         false|         true| true|                  true|    false|        false|      true|       true|        false| false|    false|    false|   false|false|     false|  false|     false|        false|    false|     false|     false|                      false|
# | Q495-GT001|          26|              false|           250.0|            300.0|               25.0|        false|           true|               true|         false|       null|      false|        false|         false|         true| true|                 false|     true|         true|     false|       true|        false| false|     true|     true|   false|false|      null|  false|     false|        false|    false|     false|     false|                      false|
# | M312-GT001|          27|              false|             0.0|           4032.0|              336.0|         true|           true|               true|         false|       null|      false|         true|         false|         true| true|                 false|    false|         true|      true|       true|        false| false|    false|     true|   false| true|      true|   true|     false|        false|    false|      true|     false|                      false|
# | B507-GT001|          28|              false|           247.5|            409.5|               63.0|        false|           true|               true|         false|       null|      false|         true|         false|         true| true|                  true|    false|         true|      true|      false|        false|  true|     true|     true|   false|false|      null|  false|     false|        false|    false|      true|     false|                      false|
# | B533-GT001|          31|              false|             0.0|           2474.5|              202.0|        false|           true|               true|          true|     2150.0|      false|         true|         false|         true| true|                  true|    false|         true|      true|       true|        false| false|    false|     true|   false|false|      null|  false|     false|        false|    false|      true|     false|                      false|
# | B439-GT001|          34|              false|          175.75|          1745.75|              125.0|        false|          false|              false|          true|      120.0|      false|        false|          true|         true| true|                  true|     true|         true|      true|      false|         true| false|    false|     true|   false|false|      null|  false|     false|        false|    false|      true|     false|                      false|
# | B409-GT001|          36|              false|            null|           2460.0|              164.0|        false|          false|               true|          true|     3500.0|      false|         true|         false|         true| true|                  true|    false|         true|      true|       true|        false| false|    false|     true|   false|false|      null|  false|     false|        false|    false|      true|     false|                      false|
# | B440-GT001|          37|              false|           197.5|           9751.5|              449.0|        false|           true|               true|         false|       null|      false|        false|         false|         true| true|                  true|    false|         true|      true|      false|        false| false|    false|     true|   false|false|      null|  false|     false|        false|    false|     false|     false|                      false|
# | B441-GT001|          38|              false|          146.25|           369.75|              21.75|        false|          false|              false|          true|      180.0|      false|        false|         false|         true| true|                 false|    false|        false|     false|      false|        false| false|     true|     true|   false|false|      null|  false|     false|        false|    false|     false|     false|                      false|
# | B442-GT001|          41|              false|           256.0|            640.0|              128.0|        false|          false|               true|          true|      120.0|      false|         true|          true|         true| true|                  true|    false|         true|      true|      false|        false| false|    false|     true|   false|false|     false|  false|     false|        false|    false|      true|     false|                      false|
# +-----------+------------+-------------------+----------------+-----------------+-------------------+-------------+---------------+-------------------+--------------+-----------+-----------+-------------+--------------+-------------+-----+----------------------+---------+-------------+----------+-----------+-------------+------+---------+---------+--------+-----+----------+-------+----------+-------------+---------+----------+----------+---------------------------+
# only showing top 20 rows

# %%
#Escolher as colunas
infquintais = episodes.select("ParksID","InspectionID","TotalFenceLength","TotalSidewalkArea","TotalSidewalkLength","OnSiteService","HydrantW_in15ft","HydrantOnGardenSide","RainHarvesting","RainGallons","SolarPanels","CompostSystem","ComposTumblers","NonFoodPlants","Food","OpenLawnOrCommunalArea","PavedArea","TreesInGarden","FruitTrees","StreetTrees","EmptyTreePits","Murals","BlankShed","ParksSign","Chickens","Pond","Turtles","Aquaponics","FarmersMarket","CSApickup","Composting","Greenhouse","StructureForSeasonExtension")
infquintais.show(truncate=False)
# Out:
# +-----------+------------+----------------+-----------------+-------------------+-------------+---------------+-------------------+--------------+-----------+-----------+-------------+--------------+-------------+-----+----------------------+---------+-------------+----------+-----------+-------------+------+---------+---------+--------+-----+-------+----------+-------------+---------+----------+----------+---------------------------+
# |ParksID    |InspectionID|TotalFenceLength|TotalSidewalkArea|TotalSidewalkLength|OnSiteService|HydrantW_in15ft|HydrantOnGardenSide|RainHarvesting|RainGallons|SolarPanels|CompostSystem|ComposTumblers|NonFoodPlants|Food |OpenLawnOrCommunalArea|PavedArea|TreesInGarden|FruitTrees|StreetTrees|EmptyTreePits|Murals|BlankShed|ParksSign|Chickens|Pond |Turtles|Aquaponics|FarmersMarket|CSApickup|Composting|Greenhouse|StructureForSeasonExtension|
# +-----------+------------+----------------+-----------------+-------------------+-------------+---------------+-------------------+--------------+-----------+-----------+-------------+--------------+-------------+-----+----------------------+---------+-------------+----------+-----------+-------------+------+---------+---------+--------+-----+-------+----------+-------------+---------+----------+----------+---------------------------+
# |B544-GT001 |1           |213.25          |276.0            |23.0               |false        |false          |true               |true          |500.0      |false      |true         |false         |true         |true |true                  |true     |true         |false     |false      |false        |false |true     |false    |true    |false|false  |false     |false        |false    |true      |true      |false                      |
# |M397-GT001 |3           |0.0             |300.0            |25.0               |false        |true           |false              |true          |200.0      |false      |false        |false         |true         |false|false                 |false    |true         |false     |false      |false        |false |false    |true     |false   |false|false  |false     |false        |false    |false     |false     |false                      |
# |M331-GT002 |5           |15.5            |160.0            |10.0               |false        |false          |false              |true          |60.0       |false      |false        |false         |true         |false|true                  |false    |true         |false     |false      |true         |false |false    |true     |false   |false|false  |false     |false        |false    |false     |false     |false                      |
# |M297A-GT001|8           |204.0           |910.0            |70.0               |false        |false          |true               |false         |null       |false      |false        |true          |true         |true |true                  |false    |true         |true      |true       |false        |false |false    |true     |false   |false|false  |false     |false        |false    |true      |false     |false                      |
# |X277-GT001 |9           |265.0           |3750.0           |150.0              |false        |false          |true               |false         |null       |false      |false        |true          |true         |true |true                  |false    |true         |true      |true       |true         |true  |true     |true     |false   |false|false  |false     |false        |false    |true      |true      |false                      |
# |B535-GT001 |15          |180.0           |1700.0           |200.0              |false        |true           |true               |true          |300.0      |true       |true         |false         |true         |true |true                  |false    |true         |true      |true       |false        |false |true     |true     |false   |false|false  |false     |false        |false    |true      |false     |false                      |
# |B575-GT001 |16          |251.0           |742.5            |49.5               |false        |false          |false              |true          |1200.0     |true       |true         |true          |true         |true |true                  |true     |true         |true      |true       |true         |false |true     |true     |false   |false|false  |false     |true         |true     |true      |false     |false                      |
# |B553-GT001 |20          |null            |364.0            |26.0               |false        |false          |false              |true          |1000.0     |true       |true         |false         |true         |true |true                  |false    |false        |false     |true       |false        |false |false    |true     |false   |false|false  |false     |false        |false    |true      |false     |false                      |
# |M313-GT001 |22          |0.0             |608.0            |76.0               |false        |true           |false              |false         |null       |true       |true         |false         |true         |false|false                 |true     |true         |true      |true       |false        |false |false    |true     |false   |true |true   |false     |false        |false    |true      |false     |false                      |
# |M293-GT001 |23          |0.0             |3240.0           |270.0              |true         |true           |true               |true          |500.0      |false      |true         |false         |true         |true |false                 |false    |true         |true      |false      |false        |true  |false    |true     |false   |true |true   |false     |false        |false    |true      |false     |false                      |
# |B438-GT001 |24          |125.0           |2280.0           |152.0              |false        |true           |true               |false         |null       |false      |false        |false         |true         |true |true                  |false    |false        |true      |true       |false        |false |false    |false    |false   |false|false  |false     |false        |false    |false     |false     |false                      |
# |Q495-GT001 |26          |250.0           |300.0            |25.0               |false        |true           |true               |false         |null       |false      |false        |false         |true         |true |false                 |true     |true         |false     |true       |false        |false |true     |true     |false   |false|false  |false     |false        |false    |false     |false     |false                      |
# |M312-GT001 |27          |0.0             |4032.0           |336.0              |true         |true           |true               |false         |null       |false      |true         |false         |true         |true |false                 |false    |true         |true      |true       |false        |false |false    |true     |false   |true |true   |false     |false        |false    |true      |false     |false                      |
# |B507-GT001 |28          |247.5           |409.5            |63.0               |false        |true           |true               |false         |null       |false      |true         |false         |true         |true |true                  |false    |true         |true      |false      |false        |true  |true     |true     |false   |false|false  |false     |false        |false    |true      |false     |false                      |
# |B533-GT001 |31          |0.0             |2474.5           |202.0              |false        |true           |true               |true          |2150.0     |false      |true         |false         |true         |true |true                  |false    |true         |true      |true       |false        |false |false    |true     |false   |false|false  |false     |false        |false    |true      |false     |false                      |
# |B439-GT001 |34          |175.75          |1745.75          |125.0              |false        |false          |false              |true          |120.0      |false      |false        |true          |true         |true |true                  |true     |true         |true      |false      |true         |false |false    |true     |false   |false|false  |false     |false        |false    |true      |false     |false                      |
# |B409-GT001 |36          |null            |2460.0           |164.0              |false        |false          |true               |true          |3500.0     |false      |true         |false         |true         |true |true                  |false    |true         |true      |true       |false        |false |false    |true     |false   |false|false  |false     |false        |false    |true      |false     |false                      |
# |B440-GT001 |37          |197.5           |9751.5           |449.0              |false        |true           |true               |false         |null       |false      |false        |false         |true         |true |true                  |false    |true         |true      |false      |false        |false |false    |true     |false   |false|false  |false     |false        |false    |false     |false     |false                      |
# |B441-GT001 |38          |146.25          |369.75           |21.75              |false        |false          |false              |true          |180.0      |false      |false        |false         |true         |true |false                 |false    |false        |false     |false      |false        |false |true     |true     |false   |false|false  |false     |false        |false    |false     |false     |false                      |
# |B442-GT001 |41          |256.0           |640.0            |128.0              |false        |false          |true               |true          |120.0      |false      |true         |true          |true         |true |true                  |false    |true         |true      |false      |false        |false |false    |true     |false   |false|false  |false     |false        |false    |true      |false     |false                      |
# +-----------+------------+----------------+-----------------+-------------------+-------------+---------------+-------------------+--------------+-----------+-----------+-------------+--------------+-------------+-----+----------------------+---------+-------------+----------+-----------+-------------+------+---------+---------+--------+-----+-------+----------+-------------+---------+----------+----------+---------------------------+
# only showing top 20 rows

# %%
# Substitui os dados a null ou vazios por 0 em caso de float/double/int e False em caso de boolean)
infquintais = infquintais.na.fill(0,["TotalFenceLength"])
infquintais = infquintais.na.fill(0,["TotalSidewalkArea"])
infquintais = infquintais.na.fill(0,["TotalSidewalkLength"])
infquintais = infquintais.na.fill(False,["OnSiteService"])
infquintais = infquintais.na.fill(False,["HydrantW_in15ft"])
infquintais = infquintais.na.fill(False,["HydrantOnGardenSide"])
infquintais = infquintais.na.fill(False,["RainHarvesting"])
infquintais = infquintais.fillna(0,["RainGallons"])
infquintais = infquintais.na.fill(False,["SolarPanels"])
infquintais = infquintais.na.fill(False,["CompostSystem"])
infquintais = infquintais.na.fill(False,["ComposTumblers"])
infquintais = infquintais.na.fill(False,["NonFoodPlants"])
infquintais = infquintais.na.fill(False,["Food"])
infquintais = infquintais.na.fill(False,["OpenLawnOrCommunalArea"])
infquintais = infquintais.na.fill(False,["PavedArea"])
infquintais = infquintais.na.fill(False,["TreesInGarden"])
infquintais = infquintais.na.fill(False,["FruitTrees"])
infquintais = infquintais.na.fill(False,["StreetTrees"])
infquintais = infquintais.na.fill(False,["EmptyTreePits"])
infquintais = infquintais.na.fill(False,["Murals"])
infquintais = infquintais.na.fill(False,["BlankShed"])
infquintais = infquintais.na.fill(False,["ParksSign"])
infquintais = infquintais.na.fill(False,["Chickens"])
infquintais = infquintais.na.fill(False,["Pond"])
infquintais = infquintais.na.fill(False,["Turtles"])
infquintais = infquintais.na.fill(False,["Aquaponics"])
infquintais = infquintais.na.fill(False,["FarmersMarket"])
infquintais = infquintais.na.fill(False,["CSApickup"])
infquintais = infquintais.na.fill(False,["Composting"])
infquintais = infquintais.na.fill(False,["Greenhouse"])
infquintais = infquintais.na.fill(False,["StructureForSeasonExtension"])
infquintais.show()
# Out:
# +-----------+------------+----------------+-----------------+-------------------+-------------+---------------+-------------------+--------------+-----------+-----------+-------------+--------------+-------------+-----+----------------------+---------+-------------+----------+-----------+-------------+------+---------+---------+--------+-----+-------+----------+-------------+---------+----------+----------+---------------------------+
# |    ParksID|InspectionID|TotalFenceLength|TotalSidewalkArea|TotalSidewalkLength|OnSiteService|HydrantW_in15ft|HydrantOnGardenSide|RainHarvesting|RainGallons|SolarPanels|CompostSystem|ComposTumblers|NonFoodPlants| Food|OpenLawnOrCommunalArea|PavedArea|TreesInGarden|FruitTrees|StreetTrees|EmptyTreePits|Murals|BlankShed|ParksSign|Chickens| Pond|Turtles|Aquaponics|FarmersMarket|CSApickup|Composting|Greenhouse|StructureForSeasonExtension|
# +-----------+------------+----------------+-----------------+-------------------+-------------+---------------+-------------------+--------------+-----------+-----------+-------------+--------------+-------------+-----+----------------------+---------+-------------+----------+-----------+-------------+------+---------+---------+--------+-----+-------+----------+-------------+---------+----------+----------+---------------------------+
# | B544-GT001|           1|          213.25|            276.0|               23.0|        false|          false|               true|          true|      500.0|      false|         true|         false|         true| true|                  true|     true|         true|     false|      false|        false| false|     true|    false|    true|false|  false|     false|        false|    false|      true|      true|                      false|
# | M397-GT001|           3|             0.0|            300.0|               25.0|        false|           true|              false|          true|      200.0|      false|        false|         false|         true|false|                 false|    false|         true|     false|      false|        false| false|    false|     true|   false|false|  false|     false|        false|    false|     false|     false|                      false|
# | M331-GT002|           5|            15.5|            160.0|               10.0|        false|          false|              false|          true|       60.0|      false|        false|         false|         true|false|                  true|    false|         true|     false|      false|         true| false|    false|     true|   false|false|  false|     false|        false|    false|     false|     false|                      false|
# |M297A-GT001|           8|           204.0|            910.0|               70.0|        false|          false|               true|         false|        0.0|      false|        false|          true|         true| true|                  true|    false|         true|      true|       true|        false| false|    false|     true|   false|false|  false|     false|        false|    false|      true|     false|                      false|
# | X277-GT001|           9|           265.0|           3750.0|              150.0|        false|          false|               true|         false|        0.0|      false|        false|          true|         true| true|                  true|    false|         true|      true|       true|         true|  true|     true|     true|   false|false|  false|     false|        false|    false|      true|      true|                      false|
# | B535-GT001|          15|           180.0|           1700.0|              200.0|        false|           true|               true|          true|      300.0|       true|         true|         false|         true| true|                  true|    false|         true|      true|       true|        false| false|     true|     true|   false|false|  false|     false|        false|    false|      true|     false|                      false|
# | B575-GT001|          16|           251.0|            742.5|               49.5|        false|          false|              false|          true|     1200.0|       true|         true|          true|         true| true|                  true|     true|         true|      true|       true|         true| false|     true|     true|   false|false|  false|     false|         true|     true|      true|     false|                      false|
# | B553-GT001|          20|             0.0|            364.0|               26.0|        false|          false|              false|          true|     1000.0|       true|         true|         false|         true| true|                  true|    false|        false|     false|       true|        false| false|    false|     true|   false|false|  false|     false|        false|    false|      true|     false|                      false|
# | M313-GT001|          22|             0.0|            608.0|               76.0|        false|           true|              false|         false|        0.0|       true|         true|         false|         true|false|                 false|     true|         true|      true|       true|        false| false|    false|     true|   false| true|   true|     false|        false|    false|      true|     false|                      false|
# | M293-GT001|          23|             0.0|           3240.0|              270.0|         true|           true|               true|          true|      500.0|      false|         true|         false|         true| true|                 false|    false|         true|      true|      false|        false|  true|    false|     true|   false| true|   true|     false|        false|    false|      true|     false|                      false|
# | B438-GT001|          24|           125.0|           2280.0|              152.0|        false|           true|               true|         false|        0.0|      false|        false|         false|         true| true|                  true|    false|        false|      true|       true|        false| false|    false|    false|   false|false|  false|     false|        false|    false|     false|     false|                      false|
# | Q495-GT001|          26|           250.0|            300.0|               25.0|        false|           true|               true|         false|        0.0|      false|        false|         false|         true| true|                 false|     true|         true|     false|       true|        false| false|     true|     true|   false|false|  false|     false|        false|    false|     false|     false|                      false|
# | M312-GT001|          27|             0.0|           4032.0|              336.0|         true|           true|               true|         false|        0.0|      false|         true|         false|         true| true|                 false|    false|         true|      true|       true|        false| false|    false|     true|   false| true|   true|     false|        false|    false|      true|     false|                      false|
# | B507-GT001|          28|           247.5|            409.5|               63.0|        false|           true|               true|         false|        0.0|      false|         true|         false|         true| true|                  true|    false|         true|      true|      false|        false|  true|     true|     true|   false|false|  false|     false|        false|    false|      true|     false|                      false|
# | B533-GT001|          31|             0.0|           2474.5|              202.0|        false|           true|               true|          true|     2150.0|      false|         true|         false|         true| true|                  true|    false|         true|      true|       true|        false| false|    false|     true|   false|false|  false|     false|        false|    false|      true|     false|                      false|
# | B439-GT001|          34|          175.75|          1745.75|              125.0|        false|          false|              false|          true|      120.0|      false|        false|          true|         true| true|                  true|     true|         true|      true|      false|         true| false|    false|     true|   false|false|  false|     false|        false|    false|      true|     false|                      false|
# | B409-GT001|          36|             0.0|           2460.0|              164.0|        false|          false|               true|          true|     3500.0|      false|         true|         false|         true| true|                  true|    false|         true|      true|       true|        false| false|    false|     true|   false|false|  false|     false|        false|    false|      true|     false|                      false|
# | B440-GT001|          37|           197.5|           9751.5|              449.0|        false|           true|               true|         false|        0.0|      false|        false|         false|         true| true|                  true|    false|         true|      true|      false|        false| false|    false|     true|   false|false|  false|     false|        false|    false|     false|     false|                      false|
# | B441-GT001|          38|          146.25|           369.75|              21.75|        false|          false|              false|          true|      180.0|      false|        false|         false|         true| true|                 false|    false|        false|     false|      false|        false| false|     true|     true|   false|false|  false|     false|        false|    false|     false|     false|                      false|
# | B442-GT001|          41|           256.0|            640.0|              128.0|        false|          false|               true|          true|      120.0|      false|         true|          true|         true| true|                  true|    false|         true|      true|      false|        false| false|    false|     true|   false|false|  false|     false|        false|    false|      true|     false|                      false|
# +-----------+------------+----------------+-----------------+-------------------+-------------+---------------+-------------------+--------------+-----------+-----------+-------------+--------------+-------------+-----+----------------------+---------+-------------+----------+-----------+-------------+------+---------+---------+--------+-----+-------+----------+-------------+---------+----------+----------+---------------------------+
# only showing top 20 rows

# %%
infquintais = infquintais.withColumn("Borough", when(infquintais.ParksID.startswith('B'), lit ("Brooklyn")) \
  .when (infquintais.ParksID.startswith ('M'), lit ("Manhattan")) \
  .when (infquintais.ParksID.startswith ('Q'), lit ("Queens")) \
  .when (infquintais.ParksID.startswith ('R'), lit ("Staten Island")) \
  .when (infquintais.ParksID.startswith ('X'), lit ("Bronx")))                               
infquintais.show();
# Out:
# +-----------+------------+----------------+-----------------+-------------------+-------------+---------------+-------------------+--------------+-----------+-----------+-------------+--------------+-------------+-----+----------------------+---------+-------------+----------+-----------+-------------+------+---------+---------+--------+-----+-------+----------+-------------+---------+----------+----------+---------------------------+---------+
# |    ParksID|InspectionID|TotalFenceLength|TotalSidewalkArea|TotalSidewalkLength|OnSiteService|HydrantW_in15ft|HydrantOnGardenSide|RainHarvesting|RainGallons|SolarPanels|CompostSystem|ComposTumblers|NonFoodPlants| Food|OpenLawnOrCommunalArea|PavedArea|TreesInGarden|FruitTrees|StreetTrees|EmptyTreePits|Murals|BlankShed|ParksSign|Chickens| Pond|Turtles|Aquaponics|FarmersMarket|CSApickup|Composting|Greenhouse|StructureForSeasonExtension|  Borough|
# +-----------+------------+----------------+-----------------+-------------------+-------------+---------------+-------------------+--------------+-----------+-----------+-------------+--------------+-------------+-----+----------------------+---------+-------------+----------+-----------+-------------+------+---------+---------+--------+-----+-------+----------+-------------+---------+----------+----------+---------------------------+---------+
# | B544-GT001|           1|          213.25|            276.0|               23.0|        false|          false|               true|          true|      500.0|      false|         true|         false|         true| true|                  true|     true|         true|     false|      false|        false| false|     true|    false|    true|false|  false|     false|        false|    false|      true|      true|                      false| Brooklyn|
# | M397-GT001|           3|             0.0|            300.0|               25.0|        false|           true|              false|          true|      200.0|      false|        false|         false|         true|false|                 false|    false|         true|     false|      false|        false| false|    false|     true|   false|false|  false|     false|        false|    false|     false|     false|                      false|Manhattan|
# | M331-GT002|           5|            15.5|            160.0|               10.0|        false|          false|              false|          true|       60.0|      false|        false|         false|         true|false|                  true|    false|         true|     false|      false|         true| false|    false|     true|   false|false|  false|     false|        false|    false|     false|     false|                      false|Manhattan|
# |M297A-GT001|           8|           204.0|            910.0|               70.0|        false|          false|               true|         false|        0.0|      false|        false|          true|         true| true|                  true|    false|         true|      true|       true|        false| false|    false|     true|   false|false|  false|     false|        false|    false|      true|     false|                      false|Manhattan|
# | X277-GT001|           9|           265.0|           3750.0|              150.0|        false|          false|               true|         false|        0.0|      false|        false|          true|         true| true|                  true|    false|         true|      true|       true|         true|  true|     true|     true|   false|false|  false|     false|        false|    false|      true|      true|                      false|    Bronx|
# | B535-GT001|          15|           180.0|           1700.0|              200.0|        false|           true|               true|          true|      300.0|       true|         true|         false|         true| true|                  true|    false|         true|      true|       true|        false| false|     true|     true|   false|false|  false|     false|        false|    false|      true|     false|                      false| Brooklyn|
# | B575-GT001|          16|           251.0|            742.5|               49.5|        false|          false|              false|          true|     1200.0|       true|         true|          true|         true| true|                  true|     true|         true|      true|       true|         true| false|     true|     true|   false|false|  false|     false|         true|     true|      true|     false|                      false| Brooklyn|
# | B553-GT001|          20|             0.0|            364.0|               26.0|        false|          false|              false|          true|     1000.0|       true|         true|         false|         true| true|                  true|    false|        false|     false|       true|        false| false|    false|     true|   false|false|  false|     false|        false|    false|      true|     false|                      false| Brooklyn|
# | M313-GT001|          22|             0.0|            608.0|               76.0|        false|           true|              false|         false|        0.0|       true|         true|         false|         true|false|                 false|     true|         true|      true|       true|        false| false|    false|     true|   false| true|   true|     false|        false|    false|      true|     false|                      false|Manhattan|
# | M293-GT001|          23|             0.0|           3240.0|              270.0|         true|           true|               true|          true|      500.0|      false|         true|         false|         true| true|                 false|    false|         true|      true|      false|        false|  true|    false|     true|   false| true|   true|     false|        false|    false|      true|     false|                      false|Manhattan|
# | B438-GT001|          24|           125.0|           2280.0|              152.0|        false|           true|               true|         false|        0.0|      false|        false|         false|         true| true|                  true|    false|        false|      true|       true|        false| false|    false|    false|   false|false|  false|     false|        false|    false|     false|     false|                      false| Brooklyn|
# | Q495-GT001|          26|           250.0|            300.0|               25.0|        false|           true|               true|         false|        0.0|      false|        false|         false|         true| true|                 false|     true|         true|     false|       true|        false| false|     true|     true|   false|false|  false|     false|        false|    false|     false|     false|                      false|   Queens|
# | M312-GT001|          27|             0.0|           4032.0|              336.0|         true|           true|               true|         false|        0.0|      false|         true|         false|         true| true|                 false|    false|         true|      true|       true|        false| false|    false|     true|   false| true|   true|     false|        false|    false|      true|     false|                      false|Manhattan|
# | B507-GT001|          28|           247.5|            409.5|               63.0|        false|           true|               true|         false|        0.0|      false|         true|         false|         true| true|                  true|    false|         true|      true|      false|        false|  true|     true|     true|   false|false|  false|     false|        false|    false|      true|     false|                      false| Brooklyn|
# | B533-GT001|          31|             0.0|           2474.5|              202.0|        false|           true|               true|          true|     2150.0|      false|         true|         false|         true| true|                  true|    false|         true|      true|       true|        false| false|    false|     true|   false|false|  false|     false|        false|    false|      true|     false|                      false| Brooklyn|
# | B439-GT001|          34|          175.75|          1745.75|              125.0|        false|          false|              false|          true|      120.0|      false|        false|          true|         true| true|                  true|     true|         true|      true|      false|         true| false|    false|     true|   false|false|  false|     false|        false|    false|      true|     false|                      false| Brooklyn|
# | B409-GT001|          36|             0.0|           2460.0|              164.0|        false|          false|               true|          true|     3500.0|      false|         true|         false|         true| true|                  true|    false|         true|      true|       true|        false| false|    false|     true|   false|false|  false|     false|        false|    false|      true|     false|                      false| Brooklyn|
# | B440-GT001|          37|           197.5|           9751.5|              449.0|        false|           true|               true|         false|        0.0|      false|        false|         false|         true| true|                  true|    false|         true|      true|      false|        false| false|    false|     true|   false|false|  false|     false|        false|    false|     false|     false|                      false| Brooklyn|
# | B441-GT001|          38|          146.25|           369.75|              21.75|        false|          false|              false|          true|      180.0|      false|        false|         false|         true| true|                 false|    false|        false|     false|      false|        false| false|     true|     true|   false|false|  false|     false|        false|    false|     false|     false|                      false| Brooklyn|
# | B442-GT001|          41|           256.0|            640.0|              128.0|        false|          false|               true|          true|      120.0|      false|         true|          true|         true| true|                  true|    false|         true|      true|      false|        false| false|    false|     true|   false|false|  false|     false|        false|    false|      true|     false|                      false| Brooklyn|
# +-----------+------------+----------------+-----------------+-------------------+-------------+---------------+-------------------+--------------+-----------+-----------+-------------+--------------+-------------+-----+----------------------+---------+-------------+----------+-----------+-------------+------+---------+---------+--------+-----+-------+----------+-------------+---------+----------+----------+---------------------------+---------+
# only showing top 20 rows

# %%
infquintais = infquintais.withColumn("Composting",col("Composting").cast(StringType()))
infquintais = infquintais.withColumn("Composting", when((infquintais.CompostSystem == True) & infquintais.ComposTumblers == True, "Both")\
.when ((infquintais.CompostSystem == True) & (infquintais.ComposTumblers == False), "Bins")\
.when ((infquintais.CompostSystem == False) & (infquintais.ComposTumblers == True), "Barrels")\
.when ((infquintais.CompostSystem == False) & (infquintais.ComposTumblers == False), "No Composting System"))
infquintais = infquintais.drop('CompostSystem')
infquintais = infquintais.drop('ComposTumblers')
infquintais.show();
# Out:
# +-----------+------------+----------------+-----------------+-------------------+-------------+---------------+-------------------+--------------+-----------+-----------+-------------+-----+----------------------+---------+-------------+----------+-----------+-------------+------+---------+---------+--------+-----+-------+----------+-------------+---------+--------------------+----------+---------------------------+---------+
# |    ParksID|InspectionID|TotalFenceLength|TotalSidewalkArea|TotalSidewalkLength|OnSiteService|HydrantW_in15ft|HydrantOnGardenSide|RainHarvesting|RainGallons|SolarPanels|NonFoodPlants| Food|OpenLawnOrCommunalArea|PavedArea|TreesInGarden|FruitTrees|StreetTrees|EmptyTreePits|Murals|BlankShed|ParksSign|Chickens| Pond|Turtles|Aquaponics|FarmersMarket|CSApickup|          Composting|Greenhouse|StructureForSeasonExtension|  Borough|
# +-----------+------------+----------------+-----------------+-------------------+-------------+---------------+-------------------+--------------+-----------+-----------+-------------+-----+----------------------+---------+-------------+----------+-----------+-------------+------+---------+---------+--------+-----+-------+----------+-------------+---------+--------------------+----------+---------------------------+---------+
# | B544-GT001|           1|          213.25|            276.0|               23.0|        false|          false|               true|          true|      500.0|      false|         true| true|                  true|     true|         true|     false|      false|        false| false|     true|    false|    true|false|  false|     false|        false|    false|                Bins|      true|                      false| Brooklyn|
# | M397-GT001|           3|             0.0|            300.0|               25.0|        false|           true|              false|          true|      200.0|      false|         true|false|                 false|    false|         true|     false|      false|        false| false|    false|     true|   false|false|  false|     false|        false|    false|No Composting System|     false|                      false|Manhattan|
# | M331-GT002|           5|            15.5|            160.0|               10.0|        false|          false|              false|          true|       60.0|      false|         true|false|                  true|    false|         true|     false|      false|         true| false|    false|     true|   false|false|  false|     false|        false|    false|No Composting System|     false|                      false|Manhattan|
# |M297A-GT001|           8|           204.0|            910.0|               70.0|        false|          false|               true|         false|        0.0|      false|         true| true|                  true|    false|         true|      true|       true|        false| false|    false|     true|   false|false|  false|     false|        false|    false|             Barrels|     false|                      false|Manhattan|
# | X277-GT001|           9|           265.0|           3750.0|              150.0|        false|          false|               true|         false|        0.0|      false|         true| true|                  true|    false|         true|      true|       true|         true|  true|     true|     true|   false|false|  false|     false|        false|    false|             Barrels|      true|                      false|    Bronx|
# | B535-GT001|          15|           180.0|           1700.0|              200.0|        false|           true|               true|          true|      300.0|       true|         true| true|                  true|    false|         true|      true|       true|        false| false|     true|     true|   false|false|  false|     false|        false|    false|                Bins|     false|                      false| Brooklyn|
# | B575-GT001|          16|           251.0|            742.5|               49.5|        false|          false|              false|          true|     1200.0|       true|         true| true|                  true|     true|         true|      true|       true|         true| false|     true|     true|   false|false|  false|     false|         true|     true|                Both|     false|                      false| Brooklyn|
# | B553-GT001|          20|             0.0|            364.0|               26.0|        false|          false|              false|          true|     1000.0|       true|         true| true|                  true|    false|        false|     false|       true|        false| false|    false|     true|   false|false|  false|     false|        false|    false|                Bins|     false|                      false| Brooklyn|
# | M313-GT001|          22|             0.0|            608.0|               76.0|        false|           true|              false|         false|        0.0|       true|         true|false|                 false|     true|         true|      true|       true|        false| false|    false|     true|   false| true|   true|     false|        false|    false|                Bins|     false|                      false|Manhattan|
# | M293-GT001|          23|             0.0|           3240.0|              270.0|         true|           true|               true|          true|      500.0|      false|         true| true|                 false|    false|         true|      true|      false|        false|  true|    false|     true|   false| true|   true|     false|        false|    false|                Bins|     false|                      false|Manhattan|
# | B438-GT001|          24|           125.0|           2280.0|              152.0|        false|           true|               true|         false|        0.0|      false|         true| true|                  true|    false|        false|      true|       true|        false| false|    false|    false|   false|false|  false|     false|        false|    false|No Composting System|     false|                      false| Brooklyn|
# | Q495-GT001|          26|           250.0|            300.0|               25.0|        false|           true|               true|         false|        0.0|      false|         true| true|                 false|     true|         true|     false|       true|        false| false|     true|     true|   false|false|  false|     false|        false|    false|No Composting System|     false|                      false|   Queens|
# | M312-GT001|          27|             0.0|           4032.0|              336.0|         true|           true|               true|         false|        0.0|      false|         true| true|                 false|    false|         true|      true|       true|        false| false|    false|     true|   false| true|   true|     false|        false|    false|                Bins|     false|                      false|Manhattan|
# | B507-GT001|          28|           247.5|            409.5|               63.0|        false|           true|               true|         false|        0.0|      false|         true| true|                  true|    false|         true|      true|      false|        false|  true|     true|     true|   false|false|  false|     false|        false|    false|                Bins|     false|                      false| Brooklyn|
# | B533-GT001|          31|             0.0|           2474.5|              202.0|        false|           true|               true|          true|     2150.0|      false|         true| true|                  true|    false|         true|      true|       true|        false| false|    false|     true|   false|false|  false|     false|        false|    false|                Bins|     false|                      false| Brooklyn|
# | B439-GT001|          34|          175.75|          1745.75|              125.0|        false|          false|              false|          true|      120.0|      false|         true| true|                  true|     true|         true|      true|      false|         true| false|    false|     true|   false|false|  false|     false|        false|    false|             Barrels|     false|                      false| Brooklyn|
# | B409-GT001|          36|             0.0|           2460.0|              164.0|        false|          false|               true|          true|     3500.0|      false|         true| true|                  true|    false|         true|      true|       true|        false| false|    false|     true|   false|false|  false|     false|        false|    false|                Bins|     false|                      false| Brooklyn|
# | B440-GT001|          37|           197.5|           9751.5|              449.0|        false|           true|               true|         false|        0.0|      false|         true| true|                  true|    false|         true|      true|      false|        false| false|    false|     true|   false|false|  false|     false|        false|    false|No Composting System|     false|                      false| Brooklyn|
# | B441-GT001|          38|          146.25|           369.75|              21.75|        false|          false|              false|          true|      180.0|      false|         true| true|                 false|    false|        false|     false|      false|        false| false|     true|     true|   false|false|  false|     false|        false|    false|No Composting System|     false|                      false| Brooklyn|
# | B442-GT001|          41|           256.0|            640.0|              128.0|        false|          false|               true|          true|      120.0|      false|         true| true|                  true|    false|         true|      true|      false|        false| false|    false|     true|   false|false|  false|     false|        false|    false|                Both|     false|                      false| Brooklyn|
# +-----------+------------+----------------+-----------------+-------------------+-------------+---------------+-------------------+--------------+-----------+-----------+-------------+-----+----------------------+---------+-------------+----------+-----------+-------------+------+---------+---------+--------+-----+-------+----------+-------------+---------+--------------------+----------+---------------------------+---------+
# only showing top 20 rows

# %%
infquintais = infquintais.withColumn("Plants", when((infquintais.NonFoodPlants == True) & infquintais.Food == True, "Both")\
.when ((infquintais.NonFoodPlants == True) & (infquintais.Food == False), "NonFood")\
.when ((infquintais.NonFoodPlants == False) & (infquintais.Food == True), "Food")\
.when ((infquintais.NonFoodPlants == False) & (infquintais.Food == False), "No Plants"))
infquintais = infquintais.drop('NonFoodPlants')
infquintais = infquintais.drop('Food')
infquintais.show();
# Out:
# +-----------+------------+----------------+-----------------+-------------------+-------------+---------------+-------------------+--------------+-----------+-----------+----------------------+---------+-------------+----------+-----------+-------------+------+---------+---------+--------+-----+-------+----------+-------------+---------+--------------------+----------+---------------------------+---------+-------+
# |    ParksID|InspectionID|TotalFenceLength|TotalSidewalkArea|TotalSidewalkLength|OnSiteService|HydrantW_in15ft|HydrantOnGardenSide|RainHarvesting|RainGallons|SolarPanels|OpenLawnOrCommunalArea|PavedArea|TreesInGarden|FruitTrees|StreetTrees|EmptyTreePits|Murals|BlankShed|ParksSign|Chickens| Pond|Turtles|Aquaponics|FarmersMarket|CSApickup|          Composting|Greenhouse|StructureForSeasonExtension|  Borough| Plants|
# +-----------+------------+----------------+-----------------+-------------------+-------------+---------------+-------------------+--------------+-----------+-----------+----------------------+---------+-------------+----------+-----------+-------------+------+---------+---------+--------+-----+-------+----------+-------------+---------+--------------------+----------+---------------------------+---------+-------+
# | B544-GT001|           1|          213.25|            276.0|               23.0|        false|          false|               true|          true|      500.0|      false|                  true|     true|         true|     false|      false|        false| false|     true|    false|    true|false|  false|     false|        false|    false|                Bins|      true|                      false| Brooklyn|   Both|
# | M397-GT001|           3|             0.0|            300.0|               25.0|        false|           true|              false|          true|      200.0|      false|                 false|    false|         true|     false|      false|        false| false|    false|     true|   false|false|  false|     false|        false|    false|No Composting System|     false|                      false|Manhattan|NonFood|
# | M331-GT002|           5|            15.5|            160.0|               10.0|        false|          false|              false|          true|       60.0|      false|                  true|    false|         true|     false|      false|         true| false|    false|     true|   false|false|  false|     false|        false|    false|No Composting System|     false|                      false|Manhattan|NonFood|
# |M297A-GT001|           8|           204.0|            910.0|               70.0|        false|          false|               true|         false|        0.0|      false|                  true|    false|         true|      true|       true|        false| false|    false|     true|   false|false|  false|     false|        false|    false|             Barrels|     false|                      false|Manhattan|   Both|
# | X277-GT001|           9|           265.0|           3750.0|              150.0|        false|          false|               true|         false|        0.0|      false|                  true|    false|         true|      true|       true|         true|  true|     true|     true|   false|false|  false|     false|        false|    false|             Barrels|      true|                      false|    Bronx|   Both|
# | B535-GT001|          15|           180.0|           1700.0|              200.0|        false|           true|               true|          true|      300.0|       true|                  true|    false|         true|      true|       true|        false| false|     true|     true|   false|false|  false|     false|        false|    false|                Bins|     false|                      false| Brooklyn|   Both|
# | B575-GT001|          16|           251.0|            742.5|               49.5|        false|          false|              false|          true|     1200.0|       true|                  true|     true|         true|      true|       true|         true| false|     true|     true|   false|false|  false|     false|         true|     true|                Both|     false|                      false| Brooklyn|   Both|
# | B553-GT001|          20|             0.0|            364.0|               26.0|        false|          false|              false|          true|     1000.0|       true|                  true|    false|        false|     false|       true|        false| false|    false|     true|   false|false|  false|     false|        false|    false|                Bins|     false|                      false| Brooklyn|   Both|
# | M313-GT001|          22|             0.0|            608.0|               76.0|        false|           true|              false|         false|        0.0|       true|                 false|     true|         true|      true|       true|        false| false|    false|     true|   false| true|   true|     false|        false|    false|                Bins|     false|                      false|Manhattan|NonFood|
# | M293-GT001|          23|             0.0|           3240.0|              270.0|         true|           true|               true|          true|      500.0|      false|                 false|    false|         true|      true|      false|        false|  true|    false|     true|   false| true|   true|     false|        false|    false|                Bins|     false|                      false|Manhattan|   Both|
# | B438-GT001|          24|           125.0|           2280.0|              152.0|        false|           true|               true|         false|        0.0|      false|                  true|    false|        false|      true|       true|        false| false|    false|    false|   false|false|  false|     false|        false|    false|No Composting System|     false|                      false| Brooklyn|   Both|
# | Q495-GT001|          26|           250.0|            300.0|               25.0|        false|           true|               true|         false|        0.0|      false|                 false|     true|         true|     false|       true|        false| false|     true|     true|   false|false|  false|     false|        false|    false|No Composting System|     false|                      false|   Queens|   Both|
# | M312-GT001|          27|             0.0|           4032.0|              336.0|         true|           true|               true|         false|        0.0|      false|                 false|    false|         true|      true|       true|        false| false|    false|     true|   false| true|   true|     false|        false|    false|                Bins|     false|                      false|Manhattan|   Both|
# | B507-GT001|          28|           247.5|            409.5|               63.0|        false|           true|               true|         false|        0.0|      false|                  true|    false|         true|      true|      false|        false|  true|     true|     true|   false|false|  false|     false|        false|    false|                Bins|     false|                      false| Brooklyn|   Both|
# | B533-GT001|          31|             0.0|           2474.5|              202.0|        false|           true|               true|          true|     2150.0|      false|                  true|    false|         true|      true|       true|        false| false|    false|     true|   false|false|  false|     false|        false|    false|                Bins|     false|                      false| Brooklyn|   Both|
# | B439-GT001|          34|          175.75|          1745.75|              125.0|        false|          false|              false|          true|      120.0|      false|                  true|     true|         true|      true|      false|         true| false|    false|     true|   false|false|  false|     false|        false|    false|             Barrels|     false|                      false| Brooklyn|   Both|
# | B409-GT001|          36|             0.0|           2460.0|              164.0|        false|          false|               true|          true|     3500.0|      false|                  true|    false|         true|      true|       true|        false| false|    false|     true|   false|false|  false|     false|        false|    false|                Bins|     false|                      false| Brooklyn|   Both|
# | B440-GT001|          37|           197.5|           9751.5|              449.0|        false|           true|               true|         false|        0.0|      false|                  true|    false|         true|      true|      false|        false| false|    false|     true|   false|false|  false|     false|        false|    false|No Composting System|     false|                      false| Brooklyn|   Both|
# | B441-GT001|          38|          146.25|           369.75|              21.75|        false|          false|              false|          true|      180.0|      false|                 false|    false|        false|     false|      false|        false| false|     true|     true|   false|false|  false|     false|        false|    false|No Composting System|     false|                      false| Brooklyn|   Both|
# | B442-GT001|          41|           256.0|            640.0|              128.0|        false|          false|               true|          true|      120.0|      false|                  true|    false|         true|      true|      false|        false| false|    false|     true|   false|false|  false|     false|        false|    false|                Both|     false|                      false| Brooklyn|   Both|
# +-----------+------------+----------------+-----------------+-------------------+-------------+---------------+-------------------+--------------+-----------+-----------+----------------------+---------+-------------+----------+-----------+-------------+------+---------+---------+--------+-----+-------+----------+-------------+---------+--------------------+----------+---------------------------+---------+-------+
# only showing top 20 rows

# %%
# As colunas HydrantW_in15ft e RainGallons serão renomeadas para consolidar a mudança de unidades dos valores das duas colunas

infquintais = infquintais.withColumnRenamed("HydrantW_in15ft","HydrantW_in5m")\
                         .withColumnRenamed("RainGallons","RainLitres")
infquintais.show();
# Out:
# +-----------+------------+----------------+-----------------+-------------------+-------------+-------------+-------------------+--------------+----------+-----------+----------------------+---------+-------------+----------+-----------+-------------+------+---------+---------+--------+-----+-------+----------+-------------+---------+--------------------+----------+---------------------------+---------+-------+
# |    ParksID|InspectionID|TotalFenceLength|TotalSidewalkArea|TotalSidewalkLength|OnSiteService|HydrantW_in5m|HydrantOnGardenSide|RainHarvesting|RainLitres|SolarPanels|OpenLawnOrCommunalArea|PavedArea|TreesInGarden|FruitTrees|StreetTrees|EmptyTreePits|Murals|BlankShed|ParksSign|Chickens| Pond|Turtles|Aquaponics|FarmersMarket|CSApickup|          Composting|Greenhouse|StructureForSeasonExtension|  Borough| Plants|
# +-----------+------------+----------------+-----------------+-------------------+-------------+-------------+-------------------+--------------+----------+-----------+----------------------+---------+-------------+----------+-----------+-------------+------+---------+---------+--------+-----+-------+----------+-------------+---------+--------------------+----------+---------------------------+---------+-------+
# | B544-GT001|           1|          213.25|            276.0|               23.0|        false|        false|               true|          true|     500.0|      false|                  true|     true|         true|     false|      false|        false| false|     true|    false|    true|false|  false|     false|        false|    false|                Bins|      true|                      false| Brooklyn|   Both|
# | M397-GT001|           3|             0.0|            300.0|               25.0|        false|         true|              false|          true|     200.0|      false|                 false|    false|         true|     false|      false|        false| false|    false|     true|   false|false|  false|     false|        false|    false|No Composting System|     false|                      false|Manhattan|NonFood|
# | M331-GT002|           5|            15.5|            160.0|               10.0|        false|        false|              false|          true|      60.0|      false|                  true|    false|         true|     false|      false|         true| false|    false|     true|   false|false|  false|     false|        false|    false|No Composting System|     false|                      false|Manhattan|NonFood|
# |M297A-GT001|           8|           204.0|            910.0|               70.0|        false|        false|               true|         false|       0.0|      false|                  true|    false|         true|      true|       true|        false| false|    false|     true|   false|false|  false|     false|        false|    false|             Barrels|     false|                      false|Manhattan|   Both|
# | X277-GT001|           9|           265.0|           3750.0|              150.0|        false|        false|               true|         false|       0.0|      false|                  true|    false|         true|      true|       true|         true|  true|     true|     true|   false|false|  false|     false|        false|    false|             Barrels|      true|                      false|    Bronx|   Both|
# | B535-GT001|          15|           180.0|           1700.0|              200.0|        false|         true|               true|          true|     300.0|       true|                  true|    false|         true|      true|       true|        false| false|     true|     true|   false|false|  false|     false|        false|    false|                Bins|     false|                      false| Brooklyn|   Both|
# | B575-GT001|          16|           251.0|            742.5|               49.5|        false|        false|              false|          true|    1200.0|       true|                  true|     true|         true|      true|       true|         true| false|     true|     true|   false|false|  false|     false|         true|     true|                Both|     false|                      false| Brooklyn|   Both|
# | B553-GT001|          20|             0.0|            364.0|               26.0|        false|        false|              false|          true|    1000.0|       true|                  true|    false|        false|     false|       true|        false| false|    false|     true|   false|false|  false|     false|        false|    false|                Bins|     false|                      false| Brooklyn|   Both|
# | M313-GT001|          22|             0.0|            608.0|               76.0|        false|         true|              false|         false|       0.0|       true|                 false|     true|         true|      true|       true|        false| false|    false|     true|   false| true|   true|     false|        false|    false|                Bins|     false|                      false|Manhattan|NonFood|
# | M293-GT001|          23|             0.0|           3240.0|              270.0|         true|         true|               true|          true|     500.0|      false|                 false|    false|         true|      true|      false|        false|  true|    false|     true|   false| true|   true|     false|        false|    false|                Bins|     false|                      false|Manhattan|   Both|
# | B438-GT001|          24|           125.0|           2280.0|              152.0|        false|         true|               true|         false|       0.0|      false|                  true|    false|        false|      true|       true|        false| false|    false|    false|   false|false|  false|     false|        false|    false|No Composting System|     false|                      false| Brooklyn|   Both|
# | Q495-GT001|          26|           250.0|            300.0|               25.0|        false|         true|               true|         false|       0.0|      false|                 false|     true|         true|     false|       true|        false| false|     true|     true|   false|false|  false|     false|        false|    false|No Composting System|     false|                      false|   Queens|   Both|
# | M312-GT001|          27|             0.0|           4032.0|              336.0|         true|         true|               true|         false|       0.0|      false|                 false|    false|         true|      true|       true|        false| false|    false|     true|   false| true|   true|     false|        false|    false|                Bins|     false|                      false|Manhattan|   Both|
# | B507-GT001|          28|           247.5|            409.5|               63.0|        false|         true|               true|         false|       0.0|      false|                  true|    false|         true|      true|      false|        false|  true|     true|     true|   false|false|  false|     false|        false|    false|                Bins|     false|                      false| Brooklyn|   Both|
# | B533-GT001|          31|             0.0|           2474.5|              202.0|        false|         true|               true|          true|    2150.0|      false|                  true|    false|         true|      true|       true|        false| false|    false|     true|   false|false|  false|     false|        false|    false|                Bins|     false|                      false| Brooklyn|   Both|
# | B439-GT001|          34|          175.75|          1745.75|              125.0|        false|        false|              false|          true|     120.0|      false|                  true|     true|         true|      true|      false|         true| false|    false|     true|   false|false|  false|     false|        false|    false|             Barrels|     false|                      false| Brooklyn|   Both|
# | B409-GT001|          36|             0.0|           2460.0|              164.0|        false|        false|               true|          true|    3500.0|      false|                  true|    false|         true|      true|       true|        false| false|    false|     true|   false|false|  false|     false|        false|    false|                Bins|     false|                      false| Brooklyn|   Both|
# | B440-GT001|          37|           197.5|           9751.5|              449.0|        false|         true|               true|         false|       0.0|      false|                  true|    false|         true|      true|      false|        false| false|    false|     true|   false|false|  false|     false|        false|    false|No Composting System|     false|                      false| Brooklyn|   Both|
# | B441-GT001|          38|          146.25|           369.75|              21.75|        false|        false|              false|          true|     180.0|      false|                 false|    false|        false|     false|      false|        false| false|     true|     true|   false|false|  false|     false|        false|    false|No Composting System|     false|                      false| Brooklyn|   Both|
# | B442-GT001|          41|           256.0|            640.0|              128.0|        false|        false|               true|          true|     120.0|      false|                  true|    false|         true|      true|      false|        false| false|    false|     true|   false|false|  false|     false|        false|    false|                Both|     false|                      false| Brooklyn|   Both|
# +-----------+------------+----------------+-----------------+-------------------+-------------+-------------+-------------------+--------------+----------+-----------+----------------------+---------+-------------+----------+-----------+-------------+------+---------+---------+--------+-----+-------+----------+-------------+---------+--------------------+----------+---------------------------+---------+-------+
# only showing top 20 rows

# %%
# Conversão da coluna "RainLitres" (anteriormente "RainGallons") de galões para litros

infquintais = infquintais.withColumn ("RainLitres", col ("RainLitres")*3.785)
infquintais.show()

# guardar as alteracoes
infquintais_guardar = infquintais.select("ParksID","Borough","InspectionID","TotalFenceLength","TotalSidewalkArea","TotalSidewalkLength","OnSiteService","HydrantW_in5m","HydrantOnGardenSide","RainHarvesting","RainLitres","SolarPanels","Composting","Plants","OpenLawnOrCommunalArea","PavedArea","TreesInGarden","FruitTrees","StreetTrees","EmptyTreePits","Murals","BlankShed","ParksSign","Chickens","Pond","Turtles","Aquaponics","FarmersMarket","CSApickup","Greenhouse","StructureForSeasonExtension")
infquintais_guardar.printSchema()
infquintais_guardar.show()
# Out:
# +-----------+------------+----------------+-----------------+-------------------+-------------+-------------+-------------------+--------------+------------------+-----------+----------------------+---------+-------------+----------+-----------+-------------+------+---------+---------+--------+-----+-------+----------+-------------+---------+--------------------+----------+---------------------------+---------+-------+
# |    ParksID|InspectionID|TotalFenceLength|TotalSidewalkArea|TotalSidewalkLength|OnSiteService|HydrantW_in5m|HydrantOnGardenSide|RainHarvesting|        RainLitres|SolarPanels|OpenLawnOrCommunalArea|PavedArea|TreesInGarden|FruitTrees|StreetTrees|EmptyTreePits|Murals|BlankShed|ParksSign|Chickens| Pond|Turtles|Aquaponics|FarmersMarket|CSApickup|          Composting|Greenhouse|StructureForSeasonExtension|  Borough| Plants|
# +-----------+------------+----------------+-----------------+-------------------+-------------+-------------+-------------------+--------------+------------------+-----------+----------------------+---------+-------------+----------+-----------+-------------+------+---------+---------+--------+-----+-------+----------+-------------+---------+--------------------+----------+---------------------------+---------+-------+
# | B544-GT001|           1|          213.25|            276.0|               23.0|        false|        false|               true|          true|            1892.5|      false|                  true|     true|         true|     false|      false|        false| false|     true|    false|    true|false|  false|     false|        false|    false|                Bins|      true|                      false| Brooklyn|   Both|
# | M397-GT001|           3|             0.0|            300.0|               25.0|        false|         true|              false|          true|             757.0|      false|                 false|    false|         true|     false|      false|        false| false|    false|     true|   false|false|  false|     false|        false|    false|No Composting System|     false|                      false|Manhattan|NonFood|
# | M331-GT002|           5|            15.5|            160.0|               10.0|        false|        false|              false|          true|227.10000000000002|      false|                  true|    false|         true|     false|      false|         true| false|    false|     true|   false|false|  false|     false|        false|    false|No Composting System|     false|                      false|Manhattan|NonFood|
# |M297A-GT001|           8|           204.0|            910.0|               70.0|        false|        false|               true|         false|               0.0|      false|                  true|    false|         true|      true|       true|        false| false|    false|     true|   false|false|  false|     false|        false|    false|             Barrels|     false|                      false|Manhattan|   Both|
# | X277-GT001|           9|           265.0|           3750.0|              150.0|        false|        false|               true|         false|               0.0|      false|                  true|    false|         true|      true|       true|         true|  true|     true|     true|   false|false|  false|     false|        false|    false|             Barrels|      true|                      false|    Bronx|   Both|
# | B535-GT001|          15|           180.0|           1700.0|              200.0|        false|         true|               true|          true|            1135.5|       true|                  true|    false|         true|      true|       true|        false| false|     true|     true|   false|false|  false|     false|        false|    false|                Bins|     false|                      false| Brooklyn|   Both|
# | B575-GT001|          16|           251.0|            742.5|               49.5|        false|        false|              false|          true|            4542.0|       true|                  true|     true|         true|      true|       true|         true| false|     true|     true|   false|false|  false|     false|         true|     true|                Both|     false|                      false| Brooklyn|   Both|
# | B553-GT001|          20|             0.0|            364.0|               26.0|        false|        false|              false|          true|            3785.0|       true|                  true|    false|        false|     false|       true|        false| false|    false|     true|   false|false|  false|     false|        false|    false|                Bins|     false|                      false| Brooklyn|   Both|
# | M313-GT001|          22|             0.0|            608.0|               76.0|        false|         true|              false|         false|               0.0|       true|                 false|     true|         true|      true|       true|        false| false|    false|     true|   false| true|   true|     false|        false|    false|                Bins|     false|                      false|Manhattan|NonFood|
# | M293-GT001|          23|             0.0|           3240.0|              270.0|         true|         true|               true|          true|            1892.5|      false|                 false|    false|         true|      true|      false|        false|  true|    false|     true|   false| true|   true|     false|        false|    false|                Bins|     false|                      false|Manhattan|   Both|
# | B438-GT001|          24|           125.0|           2280.0|              152.0|        false|         true|               true|         false|               0.0|      false|                  true|    false|        false|      true|       true|        false| false|    false|    false|   false|false|  false|     false|        false|    false|No Composting System|     false|                      false| Brooklyn|   Both|
# | Q495-GT001|          26|           250.0|            300.0|               25.0|        false|         true|               true|         false|               0.0|      false|                 false|     true|         true|     false|       true|        false| false|     true|     true|   false|false|  false|     false|        false|    false|No Composting System|     false|                      false|   Queens|   Both|
# | M312-GT001|          27|             0.0|           4032.0|              336.0|         true|         true|               true|         false|               0.0|      false|                 false|    false|         true|      true|       true|        false| false|    false|     true|   false| true|   true|     false|        false|    false|                Bins|     false|                      false|Manhattan|   Both|
# | B507-GT001|          28|           247.5|            409.5|               63.0|        false|         true|               true|         false|               0.0|      false|                  true|    false|         true|      true|      false|        false|  true|     true|     true|   false|false|  false|     false|        false|    false|                Bins|     false|                      false| Brooklyn|   Both|
# | B533-GT001|          31|             0.0|           2474.5|              202.0|        false|         true|               true|          true|           8137.75|      false|                  true|    false|         true|      true|       true|        false| false|    false|     true|   false|false|  false|     false|        false|    false|                Bins|     false|                      false| Brooklyn|   Both|
# | B439-GT001|          34|          175.75|          1745.75|              125.0|        false|        false|              false|          true|454.20000000000005|      false|                  true|     true|         true|      true|      false|         true| false|    false|     true|   false|false|  false|     false|        false|    false|             Barrels|     false|                      false| Brooklyn|   Both|
# | B409-GT001|          36|             0.0|           2460.0|              164.0|        false|        false|               true|          true|           13247.5|      false|                  true|    false|         true|      true|       true|        false| false|    false|     true|   false|false|  false|     false|        false|    false|                Bins|     false|                      false| Brooklyn|   Both|
# | B440-GT001|          37|           197.5|           9751.5|              449.0|        false|         true|               true|         false|               0.0|      false|                  true|    false|         true|      true|      false|        false| false|    false|     true|   false|false|  false|     false|        false|    false|No Composting System|     false|                      false| Brooklyn|   Both|
# | B441-GT001|          38|          146.25|           369.75|              21.75|        false|        false|              false|          true| 681.3000000000001|      false|                 false|    false|        false|     false|      false|        false| false|     true|     true|   false|false|  false|     false|        false|    false|No Composting System|     false|                      false| Brooklyn|   Both|
# | B442-GT001|          41|           256.0|            640.0|              128.0|        false|        false|               true|          true|454.20000000000005|      false|                  true|    false|         true|      true|      false|        false| false|    false|     true|   false|false|  false|     false|        false|    false|                Both|     false|                      false| Brooklyn|   Both|
# +-----------+------------+----------------+-----------------+-------------------+-------------+-------------+-------------------+--------------+------------------+-----------+----------------------+---------+-------------+----------+-----------+-------------+------+---------+---------+--------+-----+-------+----------+-------------+---------+--------------------+----------+---------------------------+---------+-------+
# only showing top 20 rows
#
# root
#  |-- ParksID: string (nullable = true)
#  |-- Borough: string (nullable = true)
#  |-- InspectionID: integer (nullable = true)
#  |-- TotalFenceLength: float (nullable = false)
#  |-- TotalSidewalkArea: float (nullable = false)
#  |-- TotalSidewalkLength: float (nullable = false)
#  |-- OnSiteService: boolean (nullable = false)
#  |-- HydrantW_in5m: boolean (nullable = false)
#  |-- HydrantOnGardenSide: boolean (nullable = false)
#  |-- RainHarvesting: boolean (nullable = false)
#  |-- RainLitres: double (nullable = false)
#  |-- SolarPanels: boolean (nullable = false)
#  |-- Composting: string (nullable = true)
#  |-- Plants: string (nullable = true)
#  |-- OpenLawnOrCommunalArea: boolean (nullable = false)
#  |-- PavedArea: boolean (nullable = false)
#  |-- TreesInGarden: boolean (nullable = false)
#  |-- FruitTrees: boolean (nullable = false)
#  |-- StreetTrees: boolean (nullable = false)
#  |-- EmptyTreePits: boolean (nullable = false)
#  |-- Murals: boolean (nullable = false)
#  |-- BlankShed: boolean (nullable = false)
#  |-- ParksSign: boolean (nullable = false)
#  |-- Chickens: boolean (nullable = false)
#  |-- Pond: boolean (nullable = false)
#  |-- Turtles: boolean (nullable = false)
#  |-- Aquaponics: boolean (nullable = false)
#  |-- FarmersMarket: boolean (nullable = false)
#  |-- CSApickup: boolean (nullable = false)
#  |-- Greenhouse: boolean (nullable = false)
#  |-- StructureForSeasonExtension: boolean (nullable = false)
#
# +-----------+---------+------------+----------------+-----------------+-------------------+-------------+-------------+-------------------+--------------+------------------+-----------+--------------------+-------+----------------------+---------+-------------+----------+-----------+-------------+------+---------+---------+--------+-----+-------+----------+-------------+---------+----------+---------------------------+
# |    ParksID|  Borough|InspectionID|TotalFenceLength|TotalSidewalkArea|TotalSidewalkLength|OnSiteService|HydrantW_in5m|HydrantOnGardenSide|RainHarvesting|        RainLitres|SolarPanels|          Composting| Plants|OpenLawnOrCommunalArea|PavedArea|TreesInGarden|FruitTrees|StreetTrees|EmptyTreePits|Murals|BlankShed|ParksSign|Chickens| Pond|Turtles|Aquaponics|FarmersMarket|CSApickup|Greenhouse|StructureForSeasonExtension|
# +-----------+---------+------------+----------------+-----------------+-------------------+-------------+-------------+-------------------+--------------+------------------+-----------+--------------------+-------+----------------------+---------+-------------+----------+-----------+-------------+------+---------+---------+--------+-----+-------+----------+-------------+---------+----------+---------------------------+
# | B544-GT001| Brooklyn|           1|          213.25|            276.0|               23.0|        false|        false|               true|          true|            1892.5|      false|                Bins|   Both|                  true|     true|         true|     false|      false|        false| false|     true|    false|    true|false|  false|     false|        false|    false|      true|                      false|
# | M397-GT001|Manhattan|           3|             0.0|            300.0|               25.0|        false|         true|              false|          true|             757.0|      false|No Composting System|NonFood|                 false|    false|         true|     false|      false|        false| false|    false|     true|   false|false|  false|     false|        false|    false|     false|                      false|
# | M331-GT002|Manhattan|           5|            15.5|            160.0|               10.0|        false|        false|              false|          true|227.10000000000002|      false|No Composting System|NonFood|                  true|    false|         true|     false|      false|         true| false|    false|     true|   false|false|  false|     false|        false|    false|     false|                      false|
# |M297A-GT001|Manhattan|           8|           204.0|            910.0|               70.0|        false|        false|               true|         false|               0.0|      false|             Barrels|   Both|                  true|    false|         true|      true|       true|        false| false|    false|     true|   false|false|  false|     false|        false|    false|     false|                      false|
# | X277-GT001|    Bronx|           9|           265.0|           3750.0|              150.0|        false|        false|               true|         false|               0.0|      false|             Barrels|   Both|                  true|    false|         true|      true|       true|         true|  true|     true|     true|   false|false|  false|     false|        false|    false|      true|                      false|
# | B535-GT001| Brooklyn|          15|           180.0|           1700.0|              200.0|        false|         true|               true|          true|            1135.5|       true|                Bins|   Both|                  true|    false|         true|      true|       true|        false| false|     true|     true|   false|false|  false|     false|        false|    false|     false|                      false|
# | B575-GT001| Brooklyn|          16|           251.0|            742.5|               49.5|        false|        false|              false|          true|            4542.0|       true|                Both|   Both|                  true|     true|         true|      true|       true|         true| false|     true|     true|   false|false|  false|     false|         true|     true|     false|                      false|
# | B553-GT001| Brooklyn|          20|             0.0|            364.0|               26.0|        false|        false|              false|          true|            3785.0|       true|                Bins|   Both|                  true|    false|        false|     false|       true|        false| false|    false|     true|   false|false|  false|     false|        false|    false|     false|                      false|
# | M313-GT001|Manhattan|          22|             0.0|            608.0|               76.0|        false|         true|              false|         false|               0.0|       true|                Bins|NonFood|                 false|     true|         true|      true|       true|        false| false|    false|     true|   false| true|   true|     false|        false|    false|     false|                      false|
# | M293-GT001|Manhattan|          23|             0.0|           3240.0|              270.0|         true|         true|               true|          true|            1892.5|      false|                Bins|   Both|                 false|    false|         true|      true|      false|        false|  true|    false|     true|   false| true|   true|     false|        false|    false|     false|                      false|
# | B438-GT001| Brooklyn|          24|           125.0|           2280.0|              152.0|        false|         true|               true|         false|               0.0|      false|No Composting System|   Both|                  true|    false|        false|      true|       true|        false| false|    false|    false|   false|false|  false|     false|        false|    false|     false|                      false|
# | Q495-GT001|   Queens|          26|           250.0|            300.0|               25.0|        false|         true|               true|         false|               0.0|      false|No Composting System|   Both|                 false|     true|         true|     false|       true|        false| false|     true|     true|   false|false|  false|     false|        false|    false|     false|                      false|
# | M312-GT001|Manhattan|          27|             0.0|           4032.0|              336.0|         true|         true|               true|         false|               0.0|      false|                Bins|   Both|                 false|    false|         true|      true|       true|        false| false|    false|     true|   false| true|   true|     false|        false|    false|     false|                      false|
# | B507-GT001| Brooklyn|          28|           247.5|            409.5|               63.0|        false|         true|               true|         false|               0.0|      false|                Bins|   Both|                  true|    false|         true|      true|      false|        false|  true|     true|     true|   false|false|  false|     false|        false|    false|     false|                      false|
# | B533-GT001| Brooklyn|          31|             0.0|           2474.5|              202.0|        false|         true|               true|          true|           8137.75|      false|                Bins|   Both|                  true|    false|         true|      true|       true|        false| false|    false|     true|   false|false|  false|     false|        false|    false|     false|                      false|
# | B439-GT001| Brooklyn|          34|          175.75|          1745.75|              125.0|        false|        false|              false|          true|454.20000000000005|      false|             Barrels|   Both|                  true|     true|         true|      true|      false|         true| false|    false|     true|   false|false|  false|     false|        false|    false|     false|                      false|
# | B409-GT001| Brooklyn|          36|             0.0|           2460.0|              164.0|        false|        false|               true|          true|           13247.5|      false|                Bins|   Both|                  true|    false|         true|      true|       true|        false| false|    false|     true|   false|false|  false|     false|        false|    false|     false|                      false|
# | B440-GT001| Brooklyn|          37|           197.5|           9751.5|              449.0|        false|         true|               true|         false|               0.0|      false|No Composting System|   Both|                  true|    false|         true|      true|      false|        false| false|    false|     true|   false|false|  false|     false|        false|    false|     false|                      false|
# | B441-GT001| Brooklyn|          38|          146.25|           369.75|              21.75|        false|        false|              false|          true| 681.3000000000001|      false|No Composting System|   Both|                 false|    false|        false|     false|      false|        false| false|     true|     true|   false|false|  false|     false|        false|    false|     false|                      false|
# | B442-GT001| Brooklyn|          41|           256.0|            640.0|              128.0|        false|        false|               true|          true|454.20000000000005|      false|                Both|   Both|                  true|    false|         true|      true|      false|        false| false|    false|     true|   false|false|  false|     false|        false|    false|     false|                      false|
# +-----------+---------+------------+----------------+-----------------+-------------------+-------------+-------------+-------------------+--------------+------------------+-----------+--------------------+-------+----------------------+---------+-------------+----------+-----------+-------------+------+---------+---------+--------+-----+-------+----------+-------------+---------+----------+---------------------------+
# only showing top 20 rows

# %%
#write df to hive deltalake_table
#.select("customer_name","month", "sales", "year")  reorder columns to match parquet table sequence
infquintais_guardar \
    .select("ParksID","Borough","InspectionID","TotalFenceLength","TotalSidewalkArea","TotalSidewalkLength","OnSiteService","HydrantW_in5m","HydrantOnGardenSide","RainHarvesting","RainLitres","SolarPanels","Composting","Plants","OpenLawnOrCommunalArea","PavedArea","TreesInGarden","FruitTrees","StreetTrees","EmptyTreePits","Murals","BlankShed","ParksSign","Chickens","Pond","Turtles","Aquaponics","FarmersMarket","CSApickup","Greenhouse","StructureForSeasonExtension") \
    .write \
    .mode("overwrite") \
    .format("delta") \
    .save("hdfs://hdfs-nn:9000/AreasVerdes/silver/InfQuintais")

# %%
spark.sql(
    """
    SHOW TABLES FROM AreasVerdes
    """
).show()
# Out:
# +-----------+--------------------+-----------+
# |  namespace|           tableName|isTemporary|
# +-----------+--------------------+-----------+
# |areasverdes|       area_sidewalk|      false|
# |areasverdes|avg_capacity_capt...|      false|
# |areasverdes|   infquintais_table|      false|
# |areasverdes|  numero_compostagem|      false|
# |areasverdes|      numero_jardins|      false|
# |areasverdes|      numero_plantas|      false|
# +-----------+--------------------+-----------+

# %%
infquintais.createOrReplaceTempView("episodes")

sqlized_df = spark.sql(
    """
    SELECT Plants
    FROM episodes
    """
)

sqlized_df.show()
# Out:
# +-------+
# | Plants|
# +-------+
# |   Both|
# |NonFood|
# |NonFood|
# |   Both|
# |   Both|
# |   Both|
# |   Both|
# |   Both|
# |NonFood|
# |   Both|
# |   Both|
# |   Both|
# |   Both|
# |   Both|
# |   Both|
# |   Both|
# |   Both|
# |   Both|
# |   Both|
# |   Both|
# +-------+
# only showing top 20 rows

# %%
spark.stop()
