# %%
from pyspark.sql import SparkSession
from pyspark.sql import Row
from delta import *
from os import PathLike
from hdfs import InsecureClient
from pyspark.sql.types import LongType, StringType, StructField, StructType, BooleanType, ArrayType, IntegerType
from pyspark.sql.functions import when, col, concat, lit

# warehouse_location points to the default location for managed databases and tables
warehouse_location = 'hdfs://hdfs-nn:9000/AreasVerdes/warehouse'

builder = SparkSession \
    .builder \
    .master("local[2]") \
    .appName("Python Spark DataFrames and SQL") \
    .config("spark.sql.warehouse.dir", warehouse_location) \
    .config("hive.metastore.uris", "thrift://hive-metastore:9083") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .config("spark.jars.packages", "io.delta:delta-core_2.12:1.0.0") \
    .enableHiveSupport() \

spark = configure_spark_with_delta_pip(builder).getOrCreate()

# %%
hdfs_path = "hdfs://hdfs-nn:9000/AreasVerdes/bronze/LocQuintais_csv/LocQuintais.csv"

# %%
# Create a DataFrame from JSON data (automatically infer schema and data types)
# There are other file formats you can read from (e.g., csv, orc, parquet)
# https://spark.apache.org/docs/2.2.0/sql-programming-guide.html#data-sources

# Read Sillicon valley episodes data
customSchema = StructType([
    StructField("assemblydist", IntegerType(), True),
    StructField("borough", StringType(), True),
    StructField("communityboard", IntegerType(), True),
    StructField("congressionaldist", IntegerType(), True),
    StructField("coundist", IntegerType(), True),
    StructField("gardenname", StringType(), True),
    StructField("juris", StringType(), True),
    StructField("multipolygon", StringType(), True),
    StructField("openhrsf", StringType(), True),
    StructField("openhrsm", StringType(), True),
    StructField("openhrssa", StringType(), True),
    StructField("openhrssu", StringType(), True),
    StructField("openhrsth", StringType(), True),
    StructField("openhrstu", StringType(), True),
    StructField("openhrsw", StringType(), True),
    StructField("parksid1", StringType(), True),
    StructField("policeprecinct", StringType(), True),
    StructField("statesenatedist", IntegerType(), True),
    StructField("status", StringType(), True),
    StructField("zipcode", IntegerType(), True)
])

LocQuintais = spark \
            .read\
            .option("delimiter",",")\
            .option("header","true")\
            .schema(customSchema) \
            .csv(hdfs_path)

# %%
# Escolho as colunas que quero
LocQuintais = LocQuintais.select("assemblydist","borough","communityboard","congressionaldist","coundist","gardenname", "juris", "multipolygon", "openhrsf", "openhrsm", "openhrssa", "openhrssu", "openhrsth", "openhrstu", "openhrsw", "parksid1","policeprecinct","statesenatedist","status","zipcode")

# %%
#substituir a informação das linhas para Unknown
LocQuintais = LocQuintais.withColumn("juris", when(LocQuintais.juris == None,"Unknown") \
      .when(LocQuintais.juris == "None","Unknown") \
      .otherwise(LocQuintais.juris))

# %%
#substituir a informação das linhas para Unknown
LocQuintais = LocQuintais.withColumn("openhrsf", when(LocQuintais.openhrsf == None,"Unknown") \
      .when(LocQuintais.openhrsf == "None","Unknown") \
      .otherwise(LocQuintais.openhrsf))

# %%
#substituir a informação das linhas para Unknown
LocQuintais = LocQuintais.withColumn("openhrsm", when(LocQuintais.openhrsm == None,"Unknown") \
      .when(LocQuintais.openhrsm == "None","Unknown") \
      .otherwise(LocQuintais.openhrsm))

# %%
#substituir a informação das linhas para Unknown
LocQuintais = LocQuintais.withColumn("openhrssa", when(LocQuintais.openhrssa == None,"Unknown") \
      .when(LocQuintais.openhrssa == "None","Unknown") \
      .otherwise(LocQuintais.openhrssa))

# %%
#substituir a informação das linhas para Unknown
LocQuintais = LocQuintais.withColumn("openhrssu", when(LocQuintais.openhrssu == None,"Unknown") \
      .when(LocQuintais.openhrssu == "None","Unknown") \
      .otherwise(LocQuintais.openhrssu))

# %%
#substituir a informação das linhas para Unknown
LocQuintais = LocQuintais.withColumn("openhrsth", when(LocQuintais.openhrsth == None,"Unknown") \
      .when(LocQuintais.openhrsth == "None","Unknown") \
      .otherwise(LocQuintais.openhrsth))

# %%
#substituir a informação das linhas para Unknown
LocQuintais = LocQuintais.withColumn("openhrstu", when(LocQuintais.openhrstu == None,"Unknown") \
      .when(LocQuintais.openhrstu == "None","Unknown") \
      .otherwise(LocQuintais.openhrstu))

# %%
#substituir a informação das linhas para Unknown

LocQuintais = LocQuintais.withColumn("openhrsw", when(LocQuintais.openhrsw == None,"Unknown") \
      .when(LocQuintais.openhrsw == "None","Unknown") \
      .otherwise(LocQuintais.openhrsw))

# %%
#substituir a informação das linhas para Unknown
LocQuintais = LocQuintais.withColumn("policeprecinct", when(LocQuintais.policeprecinct == None,"Unknown") \
      .when(LocQuintais.policeprecinct == "None","Unknown") \
      .otherwise(LocQuintais.policeprecinct))

# %%
#substituição das iniciais pelos nomes dos respetivos bairros
LocQuintais = LocQuintais.withColumn("borough", when(LocQuintais.borough == "X","Bronx") \
      .when(LocQuintais.borough == "B","Brooklyn") \
      .when(LocQuintais.borough == "M","Manhattan") \
      .when(LocQuintais.borough == "Q", "Queens") \
      .when(LocQuintais.borough == "R", "Staten Island") \
      .otherwise(LocQuintais.borough))

# %%
#ver os possiveis resultados na coluna borough
LocQuintais.createOrReplaceTempView("LocQuintais")

sqlized_df = spark.sql(
    """
    SELECT Distinct borough
    FROM LocQuintais
    """
)

sqlized_df.show()
# Out:
# +-------------+
# |      borough|
# +-------------+
# |       Queens|
# |     Brooklyn|
# |Staten Island|
# |    Manhattan|
# |        Bronx|
# +-------------+

# %%
#ver os possiveis resultados na coluna gardenname
LocQuintais.createOrReplaceTempView("LocQuintais")

sqlized_df = spark.sql(
    """
    SELECT Distinct gardenname
    FROM LocQuintais
    """
)

sqlized_df.show()
# Out:
# +--------------------+
# |          gardenname|
# +--------------------+
# |     Bayview Habitat|
# |Oko Farms Aquapon...|
# |Family Community ...|
# |NYCHA - Hylan - H...|
# |St. John's Place ...|
# | The People's Garden|
# |Morris Jumel Comm...|
# |      Garden of Love|
# |Neighbors of Vega...|
# | Bette's Rose Garden|
# |Roy Wilkins Commu...|
# | Wyckoff Bond Garden|
# |     Greene Garden .|
# |       Garden People|
# |        Dolly's Park|
# |St. Luke's Commun...|
# |      Garden of Eden|
# |Lower East Side E...|
# |   Relaxation Garden|
# |Fred McLeod Commu...|
# +--------------------+
# only showing top 20 rows

# %%
LocQuintais.toPandas()
# Out:
#      assemblydist    borough  communityboard  congressionaldist  coundist  \
# 0              79      Bronx             201                 15        17
# 1              60   Brooklyn             316                  9        42
# 2              56   Brooklyn             303                  8        36
# 3              53   Brooklyn             301                  7        34
# 4              56   Brooklyn             308                  9        36
# ..            ...        ...             ...                ...       ...
# 601            29     Queens             412                  5        27
# 602            56   Brooklyn             308                  9        36
# 603            56   Brooklyn             303                  8        36
# 604            69  Manhattan             107                 10         6
# 605            53   Brooklyn             301                 12        34
#
#                                             gardenname    juris  \
# 0                   St. Ann's Block Garden Association  Unknown
# 1                                    Gethsemane Garden  Unknown
# 2                        Hart to Hart Community Garden  Unknown
# 3    El Puente: Espiritu Tierra Community Garden - ...  Unknown
# 4                              Eden’s Community Garden  Unknown
# ..                                                 ...      ...
# 601                         Senior Citizen Garden Club  Unknown
# 602              Garden Kitchen Lab at St. John's Rec.  Unknown
# 603           Von King Park and Cultural Center Garden  Unknown
# 604                                      Garden People  Unknown
# 605                                       Orient Grove  Unknown
#
#                                           multipolygon openhrsf openhrsm  \
# 0    MULTIPOLYGON (((-73.91110273250362 40.81723264...  Unknown  Unknown
# 1    MULTIPOLYGON (((-73.90957411598448 40.65888700...  Unknown  Unknown
# 2    MULTIPOLYGON (((-73.94706962955922 40.69329106...  Unknown  Unknown
# 3    MULTIPOLYGON (((-73.95967599680367 40.71246980...  Unknown  Unknown
# 4    MULTIPOLYGON (((-73.93250525668881 40.67469872...  Unknown  Unknown
# ..                                                 ...      ...      ...
# 601  MULTIPOLYGON (((-73.77112451557377 40.68779304...  Unknown  Unknown
# 602  MULTIPOLYGON (((-73.93500081856017 40.67391829...  Unknown  Unknown
# 603  MULTIPOLYGON (((-73.9469681111235 40.689049288...  Unknown  Unknown
# 604  MULTIPOLYGON (((-73.97899093812129 40.79309028...  Unknown  Unknown
# 605  MULTIPOLYGON (((-73.9401510777611 40.714941641...  Unknown  Unknown
#
#     openhrssa openhrssu openhrsth openhrstu openhrsw    parksid1  \
# 0     Unknown   Unknown   Unknown   Unknown  Unknown  X345-GT001
# 1     Unknown   Unknown   Unknown   Unknown  Unknown  B436-GT001
# 2     Unknown   Unknown   Unknown   Unknown  Unknown  B474-GT001
# 3     Unknown   Unknown   Unknown   Unknown  Unknown  B424-GT001
# 4     Unknown   Unknown   Unknown   Unknown  Unknown  B540-GT001
# ..        ...       ...       ...       ...      ...         ...
# 601   Unknown   Unknown   Unknown   Unknown  Unknown  Q448-GT001
# 602   Unknown   Unknown   Unknown   Unknown  Unknown  B245-GT001
# 603   Unknown   Unknown   Unknown   Unknown  Unknown  B088-GT001
# 604   Unknown   Unknown   Unknown   Unknown  Unknown  M071-GT001
# 605   Unknown   Unknown   Unknown   Unknown  Unknown  B024-GT001
#
#     policeprecinct  statesenatedist                    status  zipcode
# 0          Unknown               32                    Active    10455
# 1          Unknown               19  Inactive (Group Forming)    11212
# 2          Unknown               25                    Active    11206
# 3          Unknown               18                    Active    11211
# 4          Unknown               25                    Active    11213
# ..             ...              ...                       ...      ...
# 601        Unknown               14            Not GreenThumb    11434
# 602        Unknown               25            Not GreenThumb    11213
# 603        Unknown               25            Not GreenThumb    11216
# 604        Unknown               31            Not GreenThumb    10024
# 605        Unknown               18            Not GreenThumb    11211
#
# [606 rows x 20 columns]

# %%
#write df to hive deltalake_table
#.select("customer_name","month", "sales", "year")  reorder columns to match parquet table sequence
LocQuintais \
    .select("assemblydist","borough","communityboard","congressionaldist","coundist","gardenname", "juris","multipolygon","openhrsf", "openhrsm", "openhrssa", "openhrssu", "openhrsth", "openhrstu", "openhrsw", "parksid1", "policeprecinct", "statesenatedist","status","zipcode") \
    .write \
    .mode("overwrite") \
    .format("delta") \
    .save("hdfs://hdfs-nn:9000/AreasVerdes/silver/LocQuintais")

# %%
LocQuintais.printSchema()
# Out:
# root
#  |-- assemblydist: integer (nullable = true)
#  |-- borough: string (nullable = true)
#  |-- communityboard: integer (nullable = true)
#  |-- congressionaldist: integer (nullable = true)
#  |-- coundist: integer (nullable = true)
#  |-- gardenname: string (nullable = true)
#  |-- juris: string (nullable = false)
#  |-- multipolygon: string (nullable = true)
#  |-- openhrsf: string (nullable = false)
#  |-- openhrsm: string (nullable = false)
#  |-- openhrssa: string (nullable = false)
#  |-- openhrssu: string (nullable = false)
#  |-- openhrsth: string (nullable = false)
#  |-- openhrstu: string (nullable = false)
#  |-- openhrsw: string (nullable = false)
#  |-- parksid1: string (nullable = true)
#  |-- policeprecinct: string (nullable = false)
#  |-- statesenatedist: integer (nullable = true)
#  |-- status: string (nullable = true)
#  |-- zipcode: integer (nullable = true)

# %%
LocQuintais.show()
# Out:
# +------------+---------+--------------+-----------------+--------+--------------------+-------+--------------------+--------+--------+---------+---------+---------+---------+--------+----------+--------------+---------------+--------------------+-------+
# |assemblydist|  borough|communityboard|congressionaldist|coundist|          gardenname|  juris|        multipolygon|openhrsf|openhrsm|openhrssa|openhrssu|openhrsth|openhrstu|openhrsw|   parksid|policeprecinct|statesenatedist|              status|zipcode|
# +------------+---------+--------------+-----------------+--------+--------------------+-------+--------------------+--------+--------+---------+---------+---------+---------+--------+----------+--------------+---------------+--------------------+-------+
# |          79|    Bronx|           201|               15|      17|St. Ann's Block G...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|X345-GT001|       Unknown|             32|              Active|  10455|
# |          60| Brooklyn|           316|                9|      42|   Gethsemane Garden|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|B436-GT001|       Unknown|             19|Inactive (Group F...|  11212|
# |          56| Brooklyn|           303|                8|      36|Hart to Hart Comm...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|B474-GT001|       Unknown|             25|              Active|  11206|
# |          53| Brooklyn|           301|                7|      34|El Puente: Espiri...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|B424-GT001|       Unknown|             18|              Active|  11211|
# |          56| Brooklyn|           308|                9|      36|Eden’s Community ...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|B540-GT001|       Unknown|             25|              Active|  11213|
# |          56| Brooklyn|           303|                8|      36|Garden of Life (B...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|B507-GT002|       Unknown|             25|              Active|  11233|
# |          56| Brooklyn|           303|                8|      36|NYCHA - Stuyvesan...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|    BGT176|       Unknown|             25|              Active|  11221|
# |          87|    Bronx|           209|               15|      18|NYCHA - Castle Hi...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|    XGT090|       Unknown|             32|              Active|  10473|
# |          44| Brooklyn|           314|                9|      40|Newkirk Community...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|    BGT175|       Unknown|             17|              Active|  11230|
# |          70|Manhattan|           110|               13|       9|Collyer Brothers ...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|M305-GT001|       Unknown|             30|Inactive (Group F...|  10027|
# |          79|    Bronx|           203|               15|      17|NYCHA - Union Hou...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|    XGT089|       Unknown|             32|              Active|  10459|
# |          79|    Bronx|           203|               15|      16|NYCHA - Morris II...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|    XGT088|       Unknown|             33|              Active|  10456|
# |          57| Brooklyn|           302|                8|      35|NYCHA - Farragut ...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|    BGT174|       Unknown|             25|              Active|  11201|
# |          68|Manhattan|           111|               13|       5|NYCHA - Lexington...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|    MGT101|       Unknown|             30|              Active|  10029|
# |          68|Manhattan|           111|               13|       8|NYCHA - Johnson H...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|    MGT100|       Unknown|             30|              Active|  10029|
# |          37|   Queens|           405|                7|      34|Grover Cleveland ...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|    QGT028|       Unknown|             12|Inactive (Group F...|  11385|
# |          42| Brooklyn|           314|                9|      40|Woodruff Avenue C...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|B389-GT001|       Unknown|             21|      Not GreenThumb|  11226|
# |          55| Brooklyn|           316|                8|      41|Friends of Flower...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|B464-GT002|       Unknown|             25|              Active|  11233|
# |          84| Brooklyn|           201|               15|       8|NYCHA - Patterson...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|    XGT087|       Unknown|             29|              Active|  10451|
# |          72|    Bronx|           208|               13|      10|NYCHA - Marble Hi...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|    XGT085|       Unknown|             31|              Active|  10463|
# +------------+---------+--------------+-----------------+--------+--------------------+-------+--------------------+--------+--------+---------+---------+---------+---------+--------+----------+--------------+---------------+--------------------+-------+
# only showing top 20 rows

# %%
spark.sql(
    """
    SELECT *
    FROM AreasVerdes.LocQuintais_Table
    """
).show()
# Out:
# +------------+---------+--------------+-----------------+--------+--------------------+-------+--------------------+--------+--------+---------+---------+---------+---------+--------+----------+--------------+---------------+--------------------+-------+
# |assemblydist|  borough|communityboard|congressionaldist|coundist|          gardenname|  juris|        multipolygon|openhrsf|openhrsm|openhrssa|openhrssu|openhrsth|openhrstu|openhrsw|   parksid|policeprecinct|statesenatedist|              status|zipcode|
# +------------+---------+--------------+-----------------+--------+--------------------+-------+--------------------+--------+--------+---------+---------+---------+---------+--------+----------+--------------+---------------+--------------------+-------+
# |          79|    Bronx|           201|               15|      17|St. Ann's Block G...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|X345-GT001|       Unknown|             32|              Active|  10455|
# |          60| Brooklyn|           316|                9|      42|   Gethsemane Garden|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|B436-GT001|       Unknown|             19|Inactive (Group F...|  11212|
# |          56| Brooklyn|           303|                8|      36|Hart to Hart Comm...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|B474-GT001|       Unknown|             25|              Active|  11206|
# |          53| Brooklyn|           301|                7|      34|El Puente: Espiri...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|B424-GT001|       Unknown|             18|              Active|  11211|
# |          56| Brooklyn|           308|                9|      36|Eden’s Community ...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|B540-GT001|       Unknown|             25|              Active|  11213|
# |          56| Brooklyn|           303|                8|      36|Garden of Life (B...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|B507-GT002|       Unknown|             25|              Active|  11233|
# |          56| Brooklyn|           303|                8|      36|NYCHA - Stuyvesan...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|    BGT176|       Unknown|             25|              Active|  11221|
# |          87|    Bronx|           209|               15|      18|NYCHA - Castle Hi...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|    XGT090|       Unknown|             32|              Active|  10473|
# |          44| Brooklyn|           314|                9|      40|Newkirk Community...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|    BGT175|       Unknown|             17|              Active|  11230|
# |          70|Manhattan|           110|               13|       9|Collyer Brothers ...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|M305-GT001|       Unknown|             30|Inactive (Group F...|  10027|
# |          79|    Bronx|           203|               15|      17|NYCHA - Union Hou...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|    XGT089|       Unknown|             32|              Active|  10459|
# |          79|    Bronx|           203|               15|      16|NYCHA - Morris II...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|    XGT088|       Unknown|             33|              Active|  10456|
# |          57| Brooklyn|           302|                8|      35|NYCHA - Farragut ...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|    BGT174|       Unknown|             25|              Active|  11201|
# |          68|Manhattan|           111|               13|       5|NYCHA - Lexington...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|    MGT101|       Unknown|             30|              Active|  10029|
# |          68|Manhattan|           111|               13|       8|NYCHA - Johnson H...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|    MGT100|       Unknown|             30|              Active|  10029|
# |          37|   Queens|           405|                7|      34|Grover Cleveland ...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|    QGT028|       Unknown|             12|Inactive (Group F...|  11385|
# |          42| Brooklyn|           314|                9|      40|Woodruff Avenue C...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|B389-GT001|       Unknown|             21|      Not GreenThumb|  11226|
# |          55| Brooklyn|           316|                8|      41|Friends of Flower...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|B464-GT002|       Unknown|             25|              Active|  11233|
# |          84| Brooklyn|           201|               15|       8|NYCHA - Patterson...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|    XGT087|       Unknown|             29|              Active|  10451|
# |          72|    Bronx|           208|               13|      10|NYCHA - Marble Hi...|Unknown|MULTIPOLYGON (((-...| Unknown| Unknown|  Unknown|  Unknown|  Unknown|  Unknown| Unknown|    XGT085|       Unknown|             31|              Active|  10463|
# +------------+---------+--------------+-----------------+--------+--------------------+-------+--------------------+--------+--------+---------+---------+---------+---------+--------+----------+--------------+---------------+--------------------+-------+
# only showing top 20 rows

# %%
LocQuintais=LocQuintais.select("assemblydist","borough","communityboard","congressionaldist","coundist","gardenname","multipolygon","parksid","statesenatedist","status","zipcode")

# %%
LocQuintais.printSchema()
LocQuintais.toPandas()
# Out:
# root
#  |-- assemblydist: integer (nullable = true)
#  |-- borough: string (nullable = true)
#  |-- communityboard: integer (nullable = true)
#  |-- congressionaldist: integer (nullable = true)
#  |-- coundist: integer (nullable = true)
#  |-- gardenname: string (nullable = true)
#  |-- multipolygon: string (nullable = true)
#  |-- parksid: string (nullable = true)
#  |-- statesenatedist: integer (nullable = true)
#  |-- status: string (nullable = true)
#  |-- zipcode: integer (nullable = true)
#      assemblydist    borough  communityboard  congressionaldist  coundist  \
# 0              79      Bronx             201                 15        17
# 1              60   Brooklyn             316                  9        42
# 2              56   Brooklyn             303                  8        36
# 3              53   Brooklyn             301                  7        34
# 4              56   Brooklyn             308                  9        36
# ..            ...        ...             ...                ...       ...
# 601            29     Queens             412                  5        27
# 602            56   Brooklyn             308                  9        36
# 603            56   Brooklyn             303                  8        36
# 604            69  Manhattan             107                 10         6
# 605            53   Brooklyn             301                 12        34
#
#                                             gardenname  \
# 0                   St. Ann's Block Garden Association
# 1                                    Gethsemane Garden
# 2                        Hart to Hart Community Garden
# 3    El Puente: Espiritu Tierra Community Garden - ...
# 4                              Eden’s Community Garden
# ..                                                 ...
# 601                         Senior Citizen Garden Club
# 602              Garden Kitchen Lab at St. John's Rec.
# 603           Von King Park and Cultural Center Garden
# 604                                      Garden People
# 605                                       Orient Grove
#
#                                           multipolygon     parksid  \
# 0    MULTIPOLYGON (((-73.91110273250362 40.81723264...  X345-GT001
# 1    MULTIPOLYGON (((-73.90957411598448 40.65888700...  B436-GT001
# 2    MULTIPOLYGON (((-73.94706962955922 40.69329106...  B474-GT001
# 3    MULTIPOLYGON (((-73.95967599680367 40.71246980...  B424-GT001
# 4    MULTIPOLYGON (((-73.93250525668881 40.67469872...  B540-GT001
# ..                                                 ...         ...
# 601  MULTIPOLYGON (((-73.77112451557377 40.68779304...  Q448-GT001
# 602  MULTIPOLYGON (((-73.93500081856017 40.67391829...  B245-GT001
# 603  MULTIPOLYGON (((-73.9469681111235 40.689049288...  B088-GT001
# 604  MULTIPOLYGON (((-73.97899093812129 40.79309028...  M071-GT001
# 605  MULTIPOLYGON (((-73.9401510777611 40.714941641...  B024-GT001
#
#      statesenatedist                    status  zipcode
# 0                 32                    Active    10455
# 1                 19  Inactive (Group Forming)    11212
# 2                 25                    Active    11206
# 3                 18                    Active    11211
# 4                 25                    Active    11213
# ..               ...                       ...      ...
# 601               14            Not GreenThumb    11434
# 602               25            Not GreenThumb    11213
# 603               25            Not GreenThumb    11216
# 604               31            Not GreenThumb    10024
# 605               18            Not GreenThumb    11211
#
# [606 rows x 11 columns]
